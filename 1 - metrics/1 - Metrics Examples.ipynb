# %% [markdown]
# # [Azure OpenAI Responses API's](https://learn.microsoft.com/en-us/azure/ai-services/openai/how-to/responses?tabs=python-secure#generate-a-text-response) (with Entra ID authentication)

# %%
import os, sys
from openai import AzureOpenAI
from dotenv import load_dotenv # requires python-dotenv
from azure.identity import DefaultAzureCredential, get_bearer_token_provider

if not load_dotenv("./../credentials_my.env"):
    print("Environment variables not loaded, cell execution stopped")
    sys.exit()

openai_api_version    = os.environ["AZURE_OPENAI_API_VERSION"]
azure_openai_endpoint = os.environ["AZURE_OPENAI_ENDPOINT"]
azure_deployment_name = os.environ["AZURE_OPENAI_CHAT_DEPLOYMENT_NAME"]
credential = DefaultAzureCredential()

token_provider = get_bearer_token_provider(
    credential,
    "https://ai.azure.com/.default",
)

client = AzureOpenAI(
    azure_ad_token_provider=token_provider,
    api_version=openai_api_version,
    azure_endpoint=azure_openai_endpoint
)

print(f"openai_endpoint: {client.base_url}")
print(f"azure_deployment_name: {azure_deployment_name}")
print(f"openai_api_version: {openai_api_version}")
# Out:
# openai_endpoint: https://mm-ai-upskilling-project-resourc.openai.azure.com/openai/
# azure_deployment_name: gpt-5.4-mini
# openai_api_version: 2025-04-01-preview

# %% [markdown]
# # Read the system message plus the json list of metrics

# %%
import json

# Open the system_message file in read mode
with open("system_message.txt", "r", encoding="utf-8") as file:
    system_message = file.read()

# Open the metrics file in read mode
with open("metrics.json", "r", encoding="utf-8") as file:
    metrics_list = json.loads(file.read().replace("\n", ""))

i=1
for m in metrics_list:
    print (f'{i}: {m["metric_name"]}')
    i += 1
# Out:
# 1: Intent Resolution
# 2: Tool Call Accuracy
# 3: Task Adherence
# 4: Response Completeness
# 5: Groundedness (prompt-based)
# 6: Groundedness Pro
# 7: Retrieval
# 8: Relevance
# 9: Coherence
# 10: Fluency
# 11: Similarity
# 12: F1 Score
# 13: BLEU Score
# 14: ROUGE Score
# 15: METEOR Score

# %% [markdown]
# # You may run the next cell multiple times to explore metrics samples

# %%
from IPython.display import Markdown, display

index = int(input("Which metric would you like to analyze? Please answer in English"))

display(Markdown(f"\n\n**GREAT CHOICE!** Here are a couple examples for the metric `<{metrics_list[index-1]['metric_name']}>`\n"))

messages=[{"role": "system", "content": system_message},
          {"role": "user", "content": json.dumps(metrics_list[index-1])}]

response = client.responses.create(
    model=os.environ['AZURE_OPENAI_CHAT_DEPLOYMENT_NAME'],
    input=messages)

display(Markdown(response.output_text.replace("\n", "  \n")))
# Out:
# Which metric would you like to analyze? Please answer in English 9
# **GREAT CHOICE!** Here are a couple examples for the metric `<Coherence>`
# Here are **coherence-specific** examples on a **1–5 scale**. They focus on whether the response is **logically organized, easy to follow, and directly addresses the question**.
#
# ---
#
# ### Score 5 — Excellent coherence
# **QUESTION:** How should I prepare for a job interview?
# **ANSWER:** Start by researching the company, then review the job description to match your experience. Next, practice common interview questions and prepare examples of your achievements. Finally, plan your outfit and arrival time so you feel calm and ready.
# **SCORE:** 5
# **EXPLANATION:** The response is logically ordered, uses clear transitions, and each sentence supports the preparation steps in a smooth sequence.
#
# ---
#
# ### Score 4 — Good coherence
# **QUESTION:** Explain how to reduce stress during exams.
# **ANSWER:** First, make a study schedule so you avoid last-minute pressure. Also, sleep well the night before the exam. You should take short breaks while studying, and breathing exercises can help you stay calm.
# **SCORE:** 4
# **EXPLANATION:** The answer is clear and mostly well organized, but the transitions are a little less smooth than in a top-quality response.
#
# ---
#
# ### Score 3 — Moderate coherence
# **QUESTION:** What are the benefits of exercise?
# **ANSWER:** Exercise helps the body stay healthy. It can improve mood. People also have more energy. Walking is good. Sports are fun too.
# **SCORE:** 3
# **EXPLANATION:** The response stays on topic, but the ideas feel somewhat list-like and the connections between sentences are weak.
#
# ---
#
# ### Score 2 — Low coherence
# **QUESTION:** How do I write a professional email?
# **ANSWER:** Use a greeting. Emails matter in business. Write clearly. Also, meetings can be stressful. End with your name.
# **SCORE:** 2
# **EXPLANATION:** Some relevant points appear, but the ideas jump around and one sentence is unrelated, making the response hard to follow.
#
# ---
#
# ### Score 1 — Very poor coherence
# **QUESTION:** What should I do to manage my time better?
# **ANSWER:** Time is important. The sky is blue, and meetings are loud. Better habits help. Pizza can be expensive. Planning works sometimes.
# **SCORE:** 1
# **EXPLANATION:** The response is disorganized and includes unrelated ideas, so the reader cannot follow a logical train of thought.
#
# ---
#
# If you want, I can do the same format for the next metric, such as **Fluency**, **Groundedness**, or **Relevance**.
