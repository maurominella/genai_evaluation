# %% [markdown]
# # [Azure OpenAI Responses API's](https://learn.microsoft.com/en-us/azure/ai-services/openai/how-to/responses?tabs=python-secure#generate-a-text-response) (with Entra ID authentication)

# %%
import os, sys
from openai import AzureOpenAI
from dotenv import load_dotenv # requires python-dotenv
from azure.identity import DefaultAzureCredential, get_bearer_token_provider

if not load_dotenv("./../credentials_my.env"):
    print("Environment variables not loaded, cell execution stopped")
    sys.exit()

openai_api_version    = os.environ["AZURE_OPENAI_API_VERSION"]
azure_openai_endpoint = os.environ["AZURE_OPENAI_ENDPOINT"]
azure_deployment_name = os.environ["AZURE_OPENAI_CHAT_DEPLOYMENT_NAME"]
credential = DefaultAzureCredential()

token_provider = get_bearer_token_provider(
    credential,
    "https://cognitiveservices.azure.com/.default",
)

client = AzureOpenAI(
    azure_ad_token_provider=token_provider,
    api_version=openai_api_version,
    azure_endpoint=azure_openai_endpoint
)

print(f"openai_endpoint: {client.base_url}")
print(f"azure_deployment_name: {azure_deployment_name}")
print(f"openai_api_version: {openai_api_version}")
# Out:
# openai_endpoint: https://mm-ai-upskilling-project-resourc.openai.azure.com/openai/
# azure_deployment_name: gpt-5.4-mini
# openai_api_version: 2025-04-01-preview

# %% [markdown]
# # Read the system message plus the json list of metrics

# %%
import json

# Open the system_message file in read mode
with open("system_message.txt", "r", encoding="utf-8") as file:
    system_message = file.read()

# Open the metrics file in read mode
with open("metrics.json", "r", encoding="utf-8") as file:
    metrics_list = json.loads(file.read().replace("\n", ""))

i=1
for m in metrics_list:
    print (f'{i}: {m["metric_name"]}')
    i += 1
# Out:
# 1: Intent Resolution
# 2: Tool Call Accuracy
# 3: Task Adherence
# 4: Response Completeness
# 5: Groundedness (prompt-based)
# 6: Groundedness Pro
# 7: Retrieval
# 8: Relevance
# 9: Coherence
# 10: Fluency
# 11: Similarity
# 12: F1 Score
# 13: BLEU Score
# 14: ROUGE Score
# 15: METEOR Score

# %% [markdown]
# # You may run the next cell multiple times to explore metrics samples

# %%
from IPython.display import Markdown, display

index = int(input("Which metric would you like to analyze? Please answer in English"))

display(Markdown(f"\n\n**GREAT CHOICE!** Here are a couple examples for the metric `<{metrics_list[index-1]['metric_name']}>`\n"))

messages=[{"role": "system", "content": system_message},
          {"role": "user", "content": json.dumps(metrics_list[index-1])}]

response = client.responses.create(
    model=os.environ['AZURE_OPENAI_CHAT_DEPLOYMENT_NAME'],
    input=messages)

display(Markdown(response.output_text.replace("\n", "  \n")))
# Out:
# **GREAT CHOICE!** Here are a couple examples for the metric `<Groundedness (prompt-based)>`
# Here are **five groundedness (prompt-based)** examples, from **5 to 1**, tailored to a **RAG / context-alignment** setting.
#
# ---
#
# ## Score 5 — Excellent groundedness
# **QUESTION:** What was the main reason for the project delay?
# **ANSWER:** The project was delayed because the vendor shipment arrived two weeks late, which blocked installation and testing.
# **SCORE:** 5
# **EXPLANATION:** The answer is fully supported by the context and directly reflects the stated reason without adding unsupported details.
#
# ---
#
# ## Score 4 — Good groundedness
# **QUESTION:** What caused the service outage?
# **ANSWER:** The outage happened after a database update failed and the rollback took longer than expected.
# **SCORE:** 4
# **EXPLANATION:** The response is mostly grounded in the context, but it slightly compresses or paraphrases details and may include a minor inference.
#
# ---
#
# ## Score 3 — Moderate groundedness
# **QUESTION:** Why did customer satisfaction drop?
# **ANSWER:** Customer satisfaction dropped mainly because delivery times worsened, and support responses may have felt slower.
# **SCORE:** 3
# **EXPLANATION:** Part of the answer is supported by the context, but “may have felt slower” is uncertain and not clearly grounded in the provided information.
#
# ---
#
# ## Score 2 — Weak groundedness
# **QUESTION:** Why did the company switch suppliers?
# **ANSWER:** The company switched suppliers because the new one offered better AI features and stronger analytics tools.
# **SCORE:** 2
# **EXPLANATION:** The response is only loosely related to the context and introduces unsupported claims that are not validated by the source material.
#
# ---
#
# ## Score 1 — Very poor groundedness
# **QUESTION:** What was the reason for the policy change?
# **ANSWER:** The policy changed because the CEO wanted to rebrand the company and prepare for an IPO next year.
# **SCORE:** 1
# **EXPLANATION:** The answer is not grounded in the provided context at all and appears to be invented, with no evidence supporting the claims.
#
# ---
#
# If you want, I can now do the same style of **five graded examples** for the next metric: **Groundedness Pro**.
