# %% [markdown]
# # Variables, Constants and Libraries definition

# %%
import os
from openai import AzureOpenAI
from dotenv import load_dotenv # requires python-dotenv
from azure.identity import DefaultAzureCredential, get_bearer_token_provider

if not load_dotenv("./../credentials_my.env"):
    print("Environment variables not loaded, cell execution stopped")
    sys.exit()

openai_api_version    = os.environ["AZURE_OPENAI_API_VERSION"]
azure_openai_endpoint = os.environ["AZURE_OPENAI_ENDPOINT"]
azure_deployment_name = os.environ["AZURE_OPENAI_CHAT_DEPLOYMENT_NAME"]
credential = DefaultAzureCredential()

token_provider = get_bearer_token_provider(
    credential,
    "https://ai.azure.com/.default",
)

client = AzureOpenAI(
    azure_ad_token_provider=token_provider,
    api_version=openai_api_version,
    azure_endpoint=azure_openai_endpoint
)

folder_path = "./../data"

# Create the folder if it doesn't exist
os.makedirs(folder_path, exist_ok=True)
output_file_name = os.path.join(folder_path, "questions_enriched")

# Get the current user's home directory
home_dir = os.path.expanduser("~")

print(f"openai_endpoint: {client.base_url}")
print(f"azure_deployment_name: {azure_deployment_name}")
print(f"openai_api_version: {openai_api_version}")
# Out:
# openai_endpoint: https://mm-ai-upskilling-project-resourc.openai.azure.com/openai/
# azure_deployment_name: gpt-5.4-mini
# openai_api_version: 2025-04-01-preview

# %% [markdown]
# # [Single-Topic RAG Evaluation Dataset](https://www.kaggle.com/datasets/samuelmatsuoharris/single-topic-rag-evaluation-dataset) retrieval
# There are 120 question-answer pairs in this dataset, split this way:
# - 40 questions that do not have an answer within the document.
# - 40 question-answer pairs that have an answer that must be generated from a single passage of the document.
# - 40 question-answer pairs that have an answer that must be generated from multiple passages of the document.

# %%
import os
import kagglehub
import glob
import pandas as pd

dataset_path = "./single-topic-rag-evaluation-dataset"

# Download the dataset only if the folder does not exist
if not os.path.exists(dataset_path):
    dataset_path = kagglehub.dataset_download(
        "samuelmatsuoharris/single-topic-rag-evaluation-dataset"
    )

# Load all CSV files directly from the dataset root
csv_files = glob.glob(os.path.join(dataset_path, "*.csv"))

# Create a dictionary: { file_name : dataframe }
dfs = {
    os.path.splitext(os.path.basename(file))[0]: pd.read_csv(file)
    for file in csv_files
}

# Display each dataframe
for name, df in dfs.items():
    print(f"\n\nDataframe <{name}>:")
    display(df.head())
# Out:
# Dataframe <no_answer_questions>:
#    document_index                                          question
# 0               0  How much health does the Mutant Bullet Kin have?
# 1               0                       Where can bishops be found?
# 2               1                          What happened on day 10?
# 3               1                         What did the goblins say?
# 4               2      Why was the H100 GPU chosen for computation?
# Dataframe <multi_passage_answer_questions>:
#    document_index                                           question  \
# 0               0                  Which enemy types wield an AK-47?
# 1               0               What makes jammed enemies different?
# 2               1  What enemies are encountered in the second enc...
# 3               1     What monsters are encountered in this journey?
# 4               2  What framework was chosen to execute the RAG p...
#
#                                               answer
# 0  Assault-rifle wielding Bullet and Tankers wiel...
# 1  Jammed Keybullet Kin drop 2 keys instead of 1,...
# 2  26 kobolds and 1 kobold inventor are encounter...
# 3  Ropers, kobolds, kobold inventors, fire giants...
# 4  The LangChain framework was used to orchestrat...
# Dataframe <single_passage_answer_questions>:
#    document_index                                           question  \
# 0               0                        What do keybullet kin drop?
# 1               0  What kind of gun does the bandana bullet kin use?
# 2               1                      What do the giants look like?
# 3               1                             What happens on day 2?
# 4               2        What were the requirements for the project?
#
#                                               answer
# 0               Keybullet kin drop a key upon death.
# 1    The bandana bullet kin wields a machine pistol.
# 2  One giant is burly, grey-skinned, and 20 feet ...
# 3  After a few miles of winding tunnel, you emerg...
# 4  The tool had the following requirements:\n- Ch...
# Dataframe <documents>:
#    index                                         source_url  \
# 0      0  https://enterthegungeon.fandom.com/wiki/Bullet...
# 1      1  https://www.dropbox.com/scl/fi/ljtdg6eaucrbf1a...
# 2      2  https://bytes-and-nibbles.web.app/bytes/stici-...
# 3      3              https://github.com/llmware-ai/llmware
# 4      4                https://docs.marimo.io/recipes.html
#
#                                                 text
# 0  Bullet Kin\nBullet Kin are one of the most com...
# 1  ---The Paths through the Underground/Underdark...
# 2  Semantic and Textual Inference Chatbot Interfa...
# 3  llmware\n\nBuilding Enterprise RAG Pipelines w...
# 4  Recipes\nThis page includes code snippets or “...

# %% [markdown]
# ## Prepare DataFrames and export Documents

# %%
docs_df      = dfs['documents'] # documents
ko_df        = dfs['no_answer_questions'] # no_answer_questions
questions_df = pd.concat([dfs['single_passage_answer_questions'], dfs['multi_passage_answer_questions']]) # single_passage_answer_questions + multi_passage_answer_questions

docs_df["text"].to_csv(f"{folder_path}/documents.txt", index=False, header=False)

# %% [markdown]
# # Open AI client via Azure OpenAI SDK (with Responses API's)

# %%
response = client.responses.create(
    model=azure_deployment_name,
    input="how much is 2+2?",
)

# just to check that the LLM is working
print(f"Response: {response.output_text}")
# Out:
# Response: 2 + 2 = 4.

# %% [markdown]
# # Create full evaluation dataset
# This function adds two columns:
# - `response_correct`, which is similar to `ground_truth`
# - `reponse_wrong`, which contains the wrong answer, although contextualized

# %%
def enrich_dataset(content: dict) -> dict:

    system_message = """
    given a json dictionary whose keys are "context", "query", "ground_truth", please generate two outputs, each one shorter than 30 words:
    1) "response_correct": another correct answer, possibly shorter and simpler, equivalent to the original one but with different words.
    2) "response_wrong": a wrong answer that is contextualized and may look correct to a person who doesn't know the document well, using the same style as the ground truth and the second truth
    """

    input = [
        {"role": "system", "content": system_message},
        {"role": "user", "content": json.dumps(content)}
    ]
    
    text = {
        "format": {
            "type": "json_schema",
            "name": "enriched_dataset",
            "schema": {
                "type": "object",
                "properties": {
                    "response_correct": {"type": "string"},
                    "response_wrong": {"type": "string"}
                },
                "required": ["response_correct", "response_wrong"],
                "additionalProperties": False
            },
            "strict": True
        }
    }

    response = client.responses.create(
        model = azure_deployment_name,
        input = input,
        text  = text
    )

    return json.loads(response.output_text)

# %% [markdown]
# # Consolidate the source dataframes into a single one called `consolidated_df`

# %%
# Join DataFrames on docs_df.index == multi_df.document_index
consolidated_df = questions_df.merge(docs_df, left_on='document_index', right_on='index')

# Rename columns
consolidated_df = consolidated_df.rename(columns={'text': 'context', 'question': 'query', 'answer': 'ground_truth'})

# Drop unwanted columns
consolidated_df = consolidated_df.drop(columns=['index', 'source_url'])

# Reorder columns
consolidated_df = consolidated_df[['document_index', 'context', 'query', 'ground_truth']]

consolidated_df.head()
# Out:
#    document_index                                            context  \
# 0               0  Bullet Kin\nBullet Kin are one of the most com...
# 1               0  Bullet Kin\nBullet Kin are one of the most com...
# 2               1  ---The Paths through the Underground/Underdark...
# 3               1  ---The Paths through the Underground/Underdark...
# 4               2  Semantic and Textual Inference Chatbot Interfa...
#
#                                                query  \
# 0                        What do keybullet kin drop?
# 1  What kind of gun does the bandana bullet kin use?
# 2                      What do the giants look like?
# 3                             What happens on day 2?
# 4        What were the requirements for the project?
#
#                                         ground_truth
# 0               Keybullet kin drop a key upon death.
# 1    The bandana bullet kin wields a machine pistol.
# 2  One giant is burly, grey-skinned, and 20 feet ...
# 3  After a few miles of winding tunnel, you emerg...
# 4  The tool had the following requirements:\n- Ch...

# %% [markdown]
# # Enrich `consolidated_df` into `enriched_df`

# %%
# Initialize empty lists for the new columns
response_correct_list = []
response_wrong_list = []

enriched_df = consolidated_df.copy()

i = 0
total_rows = len(enriched_df)-1

import time
import openai
import json

# Iterate over the rows using a loop
for _, row in enriched_df.iterrows():
    if i >= len(response_correct_list):
        while True:
            try:
                # Call enrich_dataset() for each row
                enriched_data = enrich_dataset({
                    "context": row['context'],
                    "query": row['query'],
                    "ground_truth": row['ground_truth']
                })

                # Ensure the expected keys exist
                if 'response_correct' in enriched_data and 'response_wrong' in enriched_data:
                    response_correct_list.append(enriched_data['response_correct'])
                    response_wrong_list.append(enriched_data['response_wrong'])

                    print(f"Index {i}/{total_rows}:\n- second_truth: <{response_correct_list[i]}>\n- wrong_answer: <{response_wrong_list[i]}>\n")
                    break  # Exit loop on success
                else:
                    print("Missing keys in enriched_data, retrying...\n")
            except openai.RateLimitError:
                print("Rate limit exceeded. Waiting for 90 seconds before retrying...\n")
                time.sleep(90)  # Wait before retrying
            except json.JSONDecodeError:
                print("JSONDecodeError encountered. Retrying enrich_dataset...\n")
                continue  # Retry enrich_dataset on JSONDecodeError
    else:
        print(f"Index {i}/{total_rows} (skipping):\n- second_truth: <{response_correct_list[i]}>\n- wrong_answer: <{response_wrong_list[i]}>\n")

    i += 1



# Assign the lists as new columns in the DataFrame
enriched_df['response_correct'] = response_correct_list
enriched_df['response_wrong'] = response_wrong_list

# Display the updated DataFrame
display(enriched_df.head())
# Out:
# Index 0/79:
# - second_truth: <They drop a key when killed.>
# - wrong_answer: <They drop a random pickup upon death.>
#
# Index 1/79:
# - second_truth: <Bandana Bullet Kin wield machine pistols.>
# - wrong_answer: <Bandana Bullet Kin wield AK-47s.>
#
# Index 2/79:
# - second_truth: <They’re huge and armored: one is grey-skinned, spiked, with tower shields; the other wears lighter iron and carries a massive maul.>
# - wrong_answer: <They’re small, pale giants in leather, each holding a crossbow and wearing no armor, both crouched behind the wall.>
#
# Index 3/79:
# - second_truth: <They enter a smaller grotto with stalactites and stalagmites, then meet 2 ropers near the next burrowed Kryn tunnel.>
# - wrong_answer: <They reach a kobold trap chamber and are ambushed by 26 kobolds and an inventor while entering the next tunnel.>
#
# Index 4/79:
# - second_truth: <It needed to answer questions from unstructured text, admit when it didn’t know, stay fast, run locally, and work well on his MacBook.>
# - wrong_answer: <It needed conversational memory, cloud hosting, and internet access, while being optimized for large servers and external APIs.>
#
# Index 5/79:
# - second_truth: <It was tested with Grace Hopper’s and Alan Turing’s Wikipedia pages.>
# - wrong_answer: <It was tested with DnD notes and the TREC 2024 RAG Corpus.>
#
# Index 6/79:
# - second_truth: <Fast start uses SQLite3 + ChromaDB; speed/scale uses MongoDB + Milvus; Postgres uses Postgres for both; mix-and-match supports many text and vector DBs.>
# - wrong_answer: <Fast start uses MongoDB and Milvus; speed/scale uses SQLite3 and ChromaDB; Postgres uses MongoDB for text and Postgres for vectors; mix-and-match supports only 5 vector DBs.>
#
# Index 7/79:
# - second_truth: <UTF-8 support for European languages was added in the v0.2.7 update on Wednesday, April 3.>
# - wrong_answer: <UTF-8 support for European languages was added in the v0.2.8 update on Tuesday, April 9.>
#
# Index 8/79:
# - second_truth: <import marimo as mo
#
# button = mo.ui.run_button()
# button
#
# mo.stop(not button.value, "Click 'run' to generate a random number")
#
# import random
# random.randint(0, 1000)>
# - wrong_answer: <import marimo as mo
#
# button = mo.ui.button(value=0, on_click=lambda c: c + 1)
# button
#
# mo.stop(button.value == 0)
#
# import random
# random.randint(0, 1000)>
#
# Index 9/79:
# - second_truth: <For expensive computations like t-SNE, UMAP, or PyMDE embeddings, caching can avoid recomputing the same results.>
# - wrong_answer: <You might use caching when you want to run a cell on a timer and refresh outputs every second.>
#
# Index 10/79:
# - second_truth: <It covers why impact matters for ICs, why it’s difficult, how to maximize it, and how to handle common barriers to real impact.>
# - wrong_answer: <It covers why output matters for ICs, why impact is easy, how to maximize productivity, and how to handle common coding challenges.>
#
# Index 11/79:
# - second_truth: <No. You can share partial credit if your work contributed to the outcome.>
# - wrong_answer: <Yes. Only the person who owns the project end-to-end should get credit for the impact.>
#
# Index 12/79:
# - second_truth: <High-risk AI systems used by public authorities, or on their behalf, must be registered in the EU database; law-enforcement and migration systems go in a restricted section.>
# - wrong_answer: <Only general-purpose AI models with systemic risks must be registered in the public EU database, while high-risk public-sector systems are exempt from registration.>
#
# Index 13/79:
# - second_truth: <Currently, general-purpose AI models trained with over 10^25 FLOPs are treated as systemic-risk models.>
# - wrong_answer: <Only high-risk AI systems in healthcare and policing are considered to carry systemic risks.>
#
# Index 14/79:
# - second_truth: <It gives the quest "Visit the Emperor's Old Hideout.">
# - wrong_answer: <It gives the player the "Help Your Protector" quest.>
#
# Index 15/79:
# - second_truth: <A group of Gish'ra warriors ambushes them.>
# - wrong_answer: <A band of Githyanki ambushes the party there.>
#
# Index 16/79:
# - second_truth: <You drank txakoli.>
# - wrong_answer: <You drank Basque cider at the pintxo bars.>
#
# Index 17/79:
# - second_truth: <Your favorite part was the four days hiking the Camino.>
# - wrong_answer: <Your favorite part of the trip was the Guggenheim Museum Bilbao tour.>
#
# Index 18/79:
# - second_truth: <They show the Polish helpers as unable to fully be themselves in public, and visually set apart as humane in a Nazi world.>
# - wrong_answer: <They mark the Hoss family’s private moments, showing how comfortable and normal they feel inside Auschwitz.>
#
# Index 19/79:
# - second_truth: <It doesn’t clearly separate perpetrators from enablers; both are treated as part of the same evil system.>
# - wrong_answer: <It sharply separates the killers from the supporters, portraying accomplices as mostly innocent bystanders.>
#
# Index 20/79:
# - second_truth: <All MPs would have half an hour of compulsory Tai Chi every day to calm Parliament down.>
# - wrong_answer: <All MPs would have half an hour of compulsory tennis every day to calm Parliament down.>
#
# Index 21/79:
# - second_truth: <Add a Daddy’s section next to the existing Mummy exhibition.>
# - wrong_answer: <The British Museum should replace the Mummy exhibition with a Father’s wing.>
#
# Index 22/79:
# - second_truth: <It’s about 1.43x to 1.70x faster, depending on the model: 1.43x for SE-ResNeXt101, 1.47x for Masked-R-CNN, and 1.70x for the Transformer task.>
# - wrong_answer: <The Tesla A100 is roughly 2x faster than the Tesla V100 across SE-ResNeXt101, Masked-R-CNN, and Transformer benchmarks.>
#
# Index 23/79:
# - second_truth: <For your sparse network training research.>
# - wrong_answer: <For your FP8 low-precision training work.>
#
# Index 24/79:
# - second_truth: <Python exports top-level functions automatically; Gleam requires `pub` to make a function public.>
# - wrong_answer: <Python keeps top-level functions private by default; Gleam exports them automatically unless marked `pub`.>
#
# Index 25/79:
# - second_truth: <In Gleam, pipe uses `|>`.>
# - wrong_answer: <In Gleam, pipe uses `>>`.>
#
# Index 26/79:
# - second_truth: <To prevent attention from seeing future tokens; softmax turns those
# nmasked positions into zeros.>
# - wrong_answer: <They’re set to negative infinity to boost future-token scores after softmax, making the model attend more strongly to upcoming tokens.>
#
# Index 27/79:
# - second_truth: <Prefix the attribute with `_`; MLX treats it as non-parameter, so it won’t be updated during training.>
# - wrong_answer: <Prefix the attribute with `#`; MLX then freezes it and keeps it from changing during optimization.>
#
# Index 28/79:
# - second_truth: <Perry is Jackie’s brother.>
# - wrong_answer: <Perry is Jackie’s husband.>
#
# Index 29/79:
# - second_truth: <Seven hundred and thirty days.>
# - wrong_answer: <The narrator had been sober for two years.>
#
# Index 30/79:
# - second_truth: <It’s called Babystation Beta.>
# - wrong_answer: <It’s called Babystation Alpha.>
#
# Index 31/79:
# - second_truth: <They all speak one language, like Cantonese.>
# - wrong_answer: <They speak English, because the Tardis translates for them.>
#
# Index 32/79:
# - second_truth: <Pet adoption was added in 1.6.3.>
# - wrong_answer: <Pet adoption was added in patch 1.6.4.>
#
# Index 33/79:
# - second_truth: <In 1.4.0, mushroom trees no longer dropped wood.>
# - wrong_answer: <In 1.5, mushroom trees stopped dropping wood.>
#
# Index 34/79:
# - second_truth: <It was officially announced at The Game Awards 2021.>
# - wrong_answer: <It was officially announced at the 2023 PlayStation Showcase.>
#
# Index 35/79:
# - second_truth: <It takes place in 2023, 13 years after Alan Wake.>
# - wrong_answer: <It takes place in 2013, just after the events of Alan Wake.>
#
# Index 36/79:
# - second_truth: <Rebecca Ross wrote Divine Rivals.>
# - wrong_answer: <Divine Rivals was written by Heather Fawcett.>
#
# Index 37/79:
# - second_truth: <Lou, together with several other murdered women, was brought back to life.>
# - wrong_answer: <Enae was resurrected with a group of other murder victims.>
#
# Index 38/79:
# - second_truth: <It splits RAG into pre-retrieval, retrieval, post-retrieval, and generation.>
# - wrong_answer: <It splits RAG into indexing, ranking, filtering, and summarization.>
#
# Index 39/79:
# - second_truth: <It can actually improve accuracy significantly, according to Noise Power.>
# - wrong_answer: <Including unrelated documents usually lowers accuracy by confusing the generator.>
#
# Index 40/79:
# - second_truth: <Assault-rifle Bullet Kin and Tankers use AK-47s.>
# - wrong_answer: <Veteran Bullet Kin and Bandana Bullet Kin wield AK-47s.>
#
# Index 41/79:
# - second_truth: <Jammed variants are tougher or more rewarding: Keybullet Kin drop two keys and move faster, Chance Kin may drop double loot, and Red-Caped Bullet Kin can deal contact damage.>
# - wrong_answer: <Jammed enemies only move faster and shoot more often; they always drop the same rewards as normal and never change contact damage.>
#
# Index 42/79:
# - second_truth: <26 kobolds and one kobold inventor are encountered.>
# - wrong_answer: <Two ropers are encountered in the second encounter.>
#
# Index 43/79:
# - second_truth: <Ropers, kobolds, kobold inventors, fire giants, and fire giant dreadnoughts.>
# - wrong_answer: <Ropers, goblins, bugbears, fire giants, and hill giants.>
#
# Index 44/79:
# - second_truth: <LangChain was chosen for the RAG pipeline; LlamaIndex and LitGPT were alternatives, and llmware came up later.>
# - wrong_answer: <LlamaIndex was chosen to orchestrate the RAG process. LangChain and AirLLM were the main alternatives, with llmware considered earlier.>
#
# Index 45/79:
# - second_truth: <Shortlisted LLMs were tinyllama-1.1b-chat-v1.0, Phi 3, dolphin-2.8-experiment26-7b-GGUF, Mistroll-7B-v2.2-GGU, and Meta-Llama-3-8B-Instruct; vector DBs were Chroma, Qdrant, and Vespa.>
# - wrong_answer: <Shortlisted LLMs were GPT-4 and Claude 3 Opus, and the vector databases were Pinecone, Weaviate, and FAISS.>
#
# Index 46/79:
# - second_truth: <It’s a small, CPU-friendly RAG-optimized instruct model in the BLING family, based on Phi-3.>
# - wrong_answer: <It’s a large DRAGON model, mainly designed for GPU-based chat and general-purpose generation.>
#
# Index 47/79:
# - second_truth: <SLIM updates appeared in 0.2.3, 0.2.6, 0.2.12, 0.3.0, and 0.3.1.>
# - wrong_answer: <SLIM models were updated in 0.2.4, 0.2.7, 0.2.13, 0.3.0, and 0.3.1.>
#
# Index 48/79:
# - second_truth: <They can be grouped as arrays, dictionaries, embedded dynamically in outputs, stacked in h/v layouts, table columns, or forms.>
# - wrong_answer: <They can be grouped as loops, lists of variables, embedded static outputs, stacked only horizontally, or cached into forms.>
#
# Index 49/79:
# - second_truth: <mo.ui.text accepts optional label and placeholder arguments.>
# - wrong_answer: <mo.ui.text takes required width and height arguments, both must be provided.>
#
# Index 50/79:
# - second_truth: <They include unused analyses, ignored experiment results, unused predictive models, and dashboards nobody views.>
# - wrong_answer: <They include unclear goals, missing buy-in, excessive ad-hoc work, and focusing too much on output instead of impact.>
#
# Index 51/79:
# - second_truth: <Understand impact for your role, solve a real business problem, get stakeholder buy-in, and spend time on the highest-impact work.>
# - wrong_answer: <Understand impact for your role, solve a real business problem, get stakeholder buy-in, and focus on the most urgent ad-hoc requests.>
#
# Index 52/79:
# - second_truth: <They are minimal risk, high-risk, unacceptable risk, and specific transparency risk.>
# - wrong_answer: <They are minimal risk, medium-risk, unacceptable risk, and general transparency risk.>
#
# Index 53/79:
# - second_truth: <General-purpose AI models must disclose information, respect copyright, and, if systemic-risk models, assess and mitigate risks, report incidents, and provide energy-consumption details.>
# - wrong_answer: <General-purpose AI models are banned unless they are open-source, and providers only need to register them after 24 months, with no extra obligations.>
#
# Index 54/79:
# - second_truth: <The Emperor is also called the Dream Guardian, Dream Visitor, and Balduran.>
# - wrong_answer: <The Emperor is also known as the Dream Guardian, the Absolute, and Orpheus.>
#
# Index 55/79:
# - second_truth: <Duke Belynne Stelmane was a key Knights of the Shield figure and the Emperor’s envoy, though it secretly enthralled her.>
# - wrong_answer: <Duke Stelmane was a Baldur’s Gate hero who openly allied with the Emperor and helped free the city from the Absolute.>
#
# Index 56/79:
# - second_truth: <At Otaegui, and also on the Camino when a cult lured you in with tea and cake.>
# - wrong_answer: <At the Guggenheim Museum Bilbao, where you enjoyed dessert during the private art tour.>
#
# Index 57/79:
# - second_truth: <We hiked the Camino and went surfing.>
# - wrong_answer: <We did biking and kayaking.>
#
# Index 58/79:
# - second_truth: <It follows the Hoss family: Rudolf, Hedwig, their five children, and Hedwig’s mother.>
# - wrong_answer: <It follows the Hoss family: Rudolf, Hedwig, their two daughters, three sons, and Rudolf’s mother.>
#
# Index 59/79:
# - second_truth: <Hedwig gets stolen luxuries like a fur coat, and the children play with gold teeth from murdered Jews.>
# - wrong_answer: <Rudolf himself takes the Jews’ jewelry, while Hedwig refuses any stolen goods and the children only play with toys.>
#
# Index 60/79:
# - second_truth: <They’d hold consultations first, shorten pregnancy to seven months, and back AstraZeneca buying Pfizer for Viagra rights.>
# - wrong_answer: <Healthcare changes include free pins for inflation, silent fireworks for animals, and yellow ducks marking potholes.>
#
# Index 61/79:
# - second_truth: <There are three: the Manicfesto proposals, the 2022 General Election Manicfesto, and the 2019 General Election Manicfesto.>
# - wrong_answer: <There are two: the 2022 Manicfesto and the 2019 Manicfesto, both presented as separate election manifestos.>
#
# Index 62/79:
# - second_truth: <He also wrote on LLM instabilities, LLM.int8(), sparse training, TPU vs GPU, and k-bit inference scaling laws.>
# - wrong_answer: <He also wrote a CUDA programming textbook, a paper on quantum GPUs, and a blog series on AMD ROCm benchmarks.>
#
# Index 63/79:
# - second_truth: <BERT Large appears in training, where its matrices fit Ada’s L2 cache, and in inference benchmarks on a 4x RTX 2080 Ti setup.>
# - wrong_answer: <BERT is only mentioned in the cache discussion for Ada GPUs; the author doesn’t discuss any inference benchmark with it.>
#
# Index 64/79:
# - second_truth: <Gleam natively supports strings, tuples, lists, and dicts.>
# - wrong_answer: <Gleam natively supports strings, sets, lists, and dictionaries.>
#
# Index 65/79:
# - second_truth: <Type mismatches cause compile errors, including bad function annotations and invalid list patterns like `[1.0, ..list]`.>
# - wrong_answer: <Only runtime value mismatches cause errors in Gleam; type mismatches compile fine, but fail when the code runs.>
#
# Index 66/79:
# - second_truth: <Broadcasting appears when comparing indices[:, None] with indices[None] for the causal mask, and when adding tok_emb and pos_emb.>
# - wrong_answer: <Broadcasting is used to split Q, K, and V into multiple attention heads before concatenation, making multi-head attention efficient.>
#
# Index 67/79:
# - second_truth: <Karpathy is cited for the Tiny Shakespeare dataset and an excellent GPT-from-scratch tutorial.>
# - wrong_answer: <Karpathy A is known as OpenAI’s GPT-2 coauthor and the inventor of byte-pair encoding.>
#
# Index 68/79:
# - second_truth: <She’d misremembered a projector room and the kitchen doorway’s location, and she thought she’d only nearly killed Perry in the crash.>
# - wrong_answer: <She misremembered the house’s paint color and thought Perry was the one driving, not her, during the accident.>
#
# Index 69/79:
# - second_truth: <Jackie was 730 days sober after crashing while drunk on Bacardi Limon. The story also mentions Jim Beam, beer, and bourbon.>
# - wrong_answer: <Jackie was sober for 730 days after a car crash caused by drinking apple cider. The story also mentions tea, wine, and vodka.>
#
# Index 70/79:
# - second_truth: <He says it in the Tardis and again as a memory beside the airlock door.>
# - wrong_answer: <He says it only once, in the control room when the babies ask about his home.>
#
# Index 71/79:
# - second_truth: <Characters include Ruby, the Doctor, Carla, Eric, Poppy, Jocelyn, Nan-E, the babies, and the Bogeyman.>
# - wrong_answer: <The main characters are Ruby, the Doctor, Carla, and the Tardis, plus several unnamed crew members.>
#
# Index 72/79:
# - second_truth: <It gives foraging XP, and it’s also used in Speed-Gro recipes.>
# - wrong_answer: <It can be crafted into deluxe fertilizer and is needed for the quarry mine shortcut.>
#
# Index 73/79:
# - second_truth: <Weeds in the Mutant Bug Lair used to become battery packs in winter, and solar panels now slowly produce them in sunlight.>
# - wrong_answer: <Lightning rods and iridium sprinklers are the only sources of battery packs; the game never mentions any other way to get them.>
#
# Index 74/79:
# - second_truth: <He rewrites "Return" into a horror story, escapes, possesses Casey, steals the Clicker, traps Saga, and is finally killed.>
# - wrong_answer: <Scratch only rewrote "Return" and then vanished, never possessing Casey or taking the Clicker.>
#
# Index 75/79:
# - second_truth: <Alice made Alan think she’d killed herself, when she’d only returned to the Dark Place to help him escape the loop.>
# - wrong_answer: <Alice tricks Alan into believing Scratch forced her suicide, while she actually left Bright Falls for good and never returned to the Dark Place.>
#
# Index 76/79:
# - second_truth: <To Shape a Dragon’s Breath, Fourth Wing, and A Day of Fallen Night feature dragons.>
# - wrong_answer: <He Who Drowned the World, Witch King, and The Terraformers all have dragons in them.>
#
# Index 77/79:
# - second_truth: <Same Bed Different Dreams, Every Drop Is a Man’s Nightmare, The Museum of Human History, Witch King, and The Terraformers.>
# - wrong_answer: <Same Bed Different Dreams, The Scarlet Alchemist, The Ferryman, Chain-Gang All-Stars, and Children of Memory.>
#
# Index 78/79:
# - second_truth: <Use text normalization (tokenization, stemming, stop-word removal) and store pretrained LM embeddings; for QA, sentence-level indexing is preferred.>
# - wrong_answer: <Index whole documents with BM25 only; sentence-level indexing is mainly used for summarization, not question-answering.>
#
# Index 79/79:
# - second_truth: <BM25 is fast and efficient, but it mainly relies on term frequency and word matches, so it can miss query semantics.>
# - wrong_answer: <BM25 is slower than dense retrieval, but it captures synonym meaning well and always ranks documents by semantic similarity.>
#    document_index                                            context  \
# 0               0  Bullet Kin\nBullet Kin are one of the most com...
# 1               0  Bullet Kin\nBullet Kin are one of the most com...
# 2               1  ---The Paths through the Underground/Underdark...
# 3               1  ---The Paths through the Underground/Underdark...
# 4               2  Semantic and Textual Inference Chatbot Interfa...
#
#                                                query  \
# 0                        What do keybullet kin drop?
# 1  What kind of gun does the bandana bullet kin use?
# 2                      What do the giants look like?
# 3                             What happens on day 2?
# 4        What were the requirements for the project?
#
#                                         ground_truth  \
# 0               Keybullet kin drop a key upon death.
# 1    The bandana bullet kin wields a machine pistol.
# 2  One giant is burly, grey-skinned, and 20 feet ...
# 3  After a few miles of winding tunnel, you emerg...
# 4  The tool had the following requirements:\n- Ch...
#
#                                     response_correct  \
# 0                       They drop a key when killed.
# 1          Bandana Bullet Kin wield machine pistols.
# 2  They’re huge and armored: one is grey-skinned,...
# 3  They enter a smaller grotto with stalactites a...
# 4  It needed to answer questions from unstructure...
#
#                                       response_wrong
# 0              They drop a random pickup upon death.
# 1                   Bandana Bullet Kin wield AK-47s.
# 2  They’re small, pale giants in leather, each ho...
# 3  They reach a kobold trap chamber and are ambus...
# 4  It needed conversational memory, cloud hosting...

# %% [markdown]
# # Save all DataFrames into CSV or JSON files

# %%
enriched_df.to_csv (f"{output_file_name}.csv", index=False)
enriched_df.to_json(f"{output_file_name}_records.jsonl", orient="records", lines=True)
enriched_df.to_json(f"{output_file_name}_split.json", orient="split")
enriched_df.to_json(f"{output_file_name}_table.json", orient="table")
enriched_df.to_json(f"{output_file_name}_index.json", orient="index")
