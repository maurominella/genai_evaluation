# %% [markdown]
# # Variables, Constants and Libraries definition

# %%
# !az login

# %%
from dotenv import load_dotenv # requires python-dotenv
from azure.identity import DefaultAzureCredential, get_bearer_token_provider #requires azure-identity
from openai import AzureOpenAI
import openai, os, json, time, glob, kagglehub # openai is used for error catching, otherwise we use AzureOpenAI
import pandas as pd

load_dotenv("./../config/credentials_my.env")

openai_endpoint       = os.environ["azure_openai_endpoint"]
openai_api_key        = os.environ["azure_openai_api_key"]
openai_api_version    = os.environ["openai_api_version"]
azure_deployment_name = os.environ["azure_openai_chat_deployment_name"]

credential            = DefaultAzureCredential()

token_provider        = get_bearer_token_provider(
    DefaultAzureCredential(), "https://cognitiveservices.azure.com/.default")

folder_path = "./enrichment"

# Create the folder if it doesn't exist
os.makedirs(folder_path, exist_ok=True)
output_file_name = os.path.join(folder_path, "questions_enriched")

# Get the current user's home directory
home_dir = os.path.expanduser("~")

# %% [markdown]
# # [Single-Topic RAG Evaluation Dataset](https://www.kaggle.com/datasets/samuelmatsuoharris/single-topic-rag-evaluation-dataset) retrieval

# %%
# Define the relative path from the home directory for the Kaggle dataset
dataset_relative_path = ".cache/kagglehub/datasets/samuelmatsuoharris/single-topic-rag-evaluation-dataset/versions/3"

dataset_path = os.path.join(home_dir, dataset_relative_path)

if not os.path.exists(dataset_path):
    dataset_path = kagglehub.dataset_download("samuelmatsuoharris/single-topic-rag-evaluation-dataset") # Download latest version

print("Path to dataset files:", dataset_path)

# Find all CSV files in the directory
csv_files = glob.glob(os.path.join(dataset_path, "*.csv"))

# Load each CSV file into a DataFrame and store them in a list
dfs = [(os.path.splitext(os.path.basename(file))[0], pd.read_csv(file)) for file in csv_files]
i=0
for df in dfs:
    print(f"\n\ndataframe #{i} <{df[0]}>:")
    display(df[1].head())
    i+=1
# Out:
# Path to dataset files: C:\Users\mauromi\.cache\kagglehub\datasets\samuelmatsuoharris\single-topic-rag-evaluation-dataset\versions\4
#
#
# dataframe #0 <documents>:
#    index                                         source_url  \
# 0      0  https://enterthegungeon.fandom.com/wiki/Bullet...
# 1      1  https://www.dropbox.com/scl/fi/ljtdg6eaucrbf1a...
# 2      2  https://bytes-and-nibbles.web.app/bytes/stici-...
# 3      3              https://github.com/llmware-ai/llmware
# 4      4                https://docs.marimo.io/recipes.html
#
#                                                 text
# 0  Bullet Kin\nBullet Kin are one of the most com...
# 1  ---The Paths through the Underground/Underdark...
# 2  Semantic and Textual Inference Chatbot Interfa...
# 3  llmware\n\nBuilding Enterprise RAG Pipelines w...
# 4  Recipes\nThis page includes code snippets or “...
# dataframe #1 <multi_passage_answer_questions>:
#    document_index                                           question  \
# 0               0                  Which enemy types wield an AK-47?
# 1               0               What makes jammed enemies different?
# 2               1  What enemies are encountered in the second enc...
# 3               1     What monsters are encountered in this journey?
# 4               2  What framework was chosen to execute the RAG p...
#
#                                               answer
# 0  Assault-rifle wielding Bullet and Tankers wiel...
# 1  Jammed Keybullet Kin drop 2 keys instead of 1,...
# 2  26 kobolds and 1 kobold inventor are encounter...
# 3  Ropers, kobolds, kobold inventors, fire giants...
# 4  The LangChain framework was used to orchestrat...
# dataframe #2 <no_answer_questions>:
#    document_index                                          question
# 0               0  How much health does the Mutant Bullet Kin have?
# 1               0                       Where can bishops be found?
# 2               1                          What happened on day 10?
# 3               1                         What did the goblins say?
# 4               2      Why was the H100 GPU chosen for computation?
# dataframe #3 <single_passage_answer_questions>:
#    document_index                                           question  \
# 0               0                        What do keybullet kin drop?
# 1               0  What kind of gun does the bandana bullet kin use?
# 2               1                      What do the giants look like?
# 3               1                             What happens on day 2?
# 4               2        What were the requirements for the project?
#
#                                               answer
# 0               Keybullet kin drop a key upon death.
# 1    The bandana bullet kin wields a machine pistol.
# 2  One giant is burly, grey-skinned, and 20 feet ...
# 3  After a few miles of winding tunnel, you emerg...
# 4  The tool had the following requirements:\n- Ch...

# %%
docs_df      = dfs[0][1] # documents
ko_df        = dfs[2][1] # no_answer_questions
questions_df = pd.concat([dfs[3][1], dfs[1][1]]) # single_passage_answer_questions + multi_passage_answer_questions
docs_df["text"].to_csv(f"{folder_path}/documents.txt", index=False, header=False, sep="\n")

# %% [markdown]
# # Open AI client via Azure OpenAI SDK (with Responses API's)

# %%
client = AzureOpenAI(
    azure_ad_token_provider = token_provider,
    api_version = openai_api_version)

response = client.responses.create(
    model = azure_deployment_name,
    input="how can I make a good pizza?")

print(f"Response: {response.output_text[:30]}...")
# Out:
# Response: Making a good pizza involves s...

# %% [markdown]
# # Create full evaluation dataset

# %%
def enrich_dataset(content: dict) -> dict:

    system_message = """
    given a json dictionary whose keys are "context", "query", "ground_truth", please generate two outputs:
    1) "response_correct": another correct answer, possibly shorter and simpler, equivalent to the original one but with different words.
    2) "response_wrong": a wrong answer that is contextualized and may look correct to a person who doesn't know the document well, using the same style as the ground truth and the second truth
    """

    input = [
        {"role": "system", "content": system_message},
        {"role": "user", "content": json.dumps(content)}
    ]
    
    text = {
        "format": {
            "type": "json_schema",
            "name": "enriched_dataset",
            "schema": {
                "type": "object",
                "properties": {
                    "response_correct": {"type": "string"},
                    "response_wrong": {"type": "string"}
                },
                "required": ["response_correct", "response_wrong"],
                "additionalProperties": False
            },
            "strict": True
        }
    }

    response = client.responses.create(
        model = azure_deployment_name,
        input = input,
        text  = text
    )

    return json.loads(response.output_text)

# %% [markdown]
# # Consolidate the source dataframes into a single one called `consolidated_df`

# %%
# Join DataFrames on docs_df.index == multi_df.document_index
consolidated_df = questions_df.merge(docs_df, left_on='document_index', right_on='index')

# Rename columns
consolidated_df = consolidated_df.rename(columns={'text': 'context', 'question': 'query', 'answer': 'ground_truth'})

# Drop unwanted columns
consolidated_df = consolidated_df.drop(columns=['index', 'source_url'])

# Reorder columns
consolidated_df = consolidated_df[['document_index', 'context', 'query', 'ground_truth']]

consolidated_df.head()
# Out:
#    document_index                                            context  \
# 0               0  Bullet Kin\nBullet Kin are one of the most com...
# 1               0  Bullet Kin\nBullet Kin are one of the most com...
# 2               1  ---The Paths through the Underground/Underdark...
# 3               1  ---The Paths through the Underground/Underdark...
# 4               2  Semantic and Textual Inference Chatbot Interfa...
#
#                                                query  \
# 0                        What do keybullet kin drop?
# 1  What kind of gun does the bandana bullet kin use?
# 2                      What do the giants look like?
# 3                             What happens on day 2?
# 4        What were the requirements for the project?
#
#                                         ground_truth
# 0               Keybullet kin drop a key upon death.
# 1    The bandana bullet kin wields a machine pistol.
# 2  One giant is burly, grey-skinned, and 20 feet ...
# 3  After a few miles of winding tunnel, you emerg...
# 4  The tool had the following requirements:\n- Ch...

# %% [markdown]
# # Enrich `consolidated_df` into `enriched_df`

# %%
# Initialize empty lists for the new columns
response_correct_list = []
response_wrong_list = []

enriched_df = consolidated_df.copy()

i = 0
total_rows = len(enriched_df)-1

import time
import openai
import json

# Iterate over the rows using a loop
for _, row in enriched_df.iterrows():
    if i >= len(response_correct_list):
        while True:
            try:
                # Call enrich_dataset() for each row
                enriched_data = enrich_dataset({
                    "context": row['context'],
                    "query": row['query'],
                    "ground_truth": row['ground_truth']
                })

                # Ensure the expected keys exist
                if 'response_correct' in enriched_data and 'response_wrong' in enriched_data:
                    response_correct_list.append(enriched_data['response_correct'])
                    response_wrong_list.append(enriched_data['response_wrong'])

                    print(f"Index {i}/{total_rows}:\n- second_truth: <{response_correct_list[i]}>\n- wrong_answer: <{response_wrong_list[i]}>\n")
                    break  # Exit loop on success
                else:
                    print("Missing keys in enriched_data, retrying...\n")
            except openai.RateLimitError:
                print("Rate limit exceeded. Waiting for 90 seconds before retrying...\n")
                time.sleep(90)  # Wait before retrying
            except json.JSONDecodeError:
                print("JSONDecodeError encountered. Retrying enrich_dataset...\n")
                continue  # Retry enrich_dataset on JSONDecodeError
    else:
        print(f"Index {i}/{total_rows} (skipping):\n- second_truth: <{response_correct_list[i]}>\n- wrong_answer: <{response_wrong_list[i]}>\n")

    i += 1



# Assign the lists as new columns in the DataFrame
enriched_df['response_correct'] = response_correct_list
enriched_df['response_wrong'] = response_wrong_list

# Display the updated DataFrame
display(enriched_df.head())
# Out:
# Index 0/79:
# - second_truth: <Keybullet Kin drop keys when killed.>
# - wrong_answer: <Keybullet Kin drop health packs when defeated.>
#
# Index 1/79:
# - second_truth: <Bandana Bullet Kin carry machine pistols.>
# - wrong_answer: <Bandana Bullet Kin are equipped with magnums.>
#
# Index 2/79:
# - second_truth: <One giant is massive, with grey skin and stands 20 feet tall, wearing dark iron armor covered in sharp spikes and holding large tower shields with spikes.
#
# The other is another tall giant dressed in flexible iron armor, holding a huge maul and looking bored.>
# - wrong_answer: <The giants are slender and gold-skinned, about 10 feet tall. They wear light leather armor and carry small bucklers without any spikes, appearing ready for a quick escape.>
#
# Index 3/79:
# - second_truth: <You come across two ropers in a small grotto full of stalactites and stalagmites dripping with water. Groundwater funnels into this area.>
# - wrong_answer: <You find yourself in a vast cavern filled with giant mushrooms and encounter goblin guards who block your path, demanding you pay a toll to continue.>
#
# Index 4/79:
# - second_truth: <The project requirements were:
# - A chatbot for asking questions and receiving answers (no conversational memory needed).
# - Using information from unstructured text files.
# - Ability to indicate unknown answers.
# - Quick performance.
# - Efficient enough to run smoothly on a MacBook alongside other applications.
# - Must operate locally for privacy and to be always free and reliable.>
# - wrong_answer: <The project needed:
# - A chatbot that preserves conversational history.
# - Answers derived from structured text documents.
# - Ability to generate answers even if the information is unknown.
# - Slow performance to save resources.
# - Requirement to use an external server for privacy and efficiency.>
#
# Index 5/79:
# - second_truth: <Grace Hopper and Alan Turing’s Wikipedia pages were used to test the prototype.>
# - wrong_answer: <The prototype was tested with the Wikipedia pages of Ada Lovelace and Charles Babbage.>
#
# Index 6/79:
# - second_truth: <For quick setup, use SQLite3 and ChromaDB. For larger projects, use MongoDB and Milvus, installing them with Docker Compose. Postgres works for both text and vector storage and also uses Docker Compose. You can mix and match using 3 text databases (MongoDB, Postgres, SQLite) and 10 vector databases.>
# - wrong_answer: <Start with SQLite3 for basic setup and Milvus with Docker for advanced needs. Use MongoDB for text storage and ChromaDB for more complex vector requirements. Postgres requires additional configuration and supports limited integration with vector databases.>
#
# Index 7/79:
# - second_truth: <Support for UTF-8 encoding for European languages was added on April 3, according to the v0.2.7 update.>
# - wrong_answer: <UTF-8 support for European languages was introduced on March 22 during the v0.2.6 update.>
#
# Index 8/79:
# - second_truth: <import marimo as mo
#
# button = mo.ui.run_button()
# button
#
# mo.stop(not button.value, "Press 'run' to generate a random number")
#
# import random
# random.randint(0, 1000)>
# - wrong_answer: <import marimo as mo
#
# button = mo.ui.slider(0, 10)
# button
#
# mo.stop(button.value < 5, "Slide to 'run' to generate a random number")
#
# import random
# random.randint(0, 500)>
#
# Index 9/79:
# - second_truth: <Caching is useful when your notebook performs computations like t-SNE, UMAP, or PyMDE embeddings.>
# - wrong_answer: <Caching should be used when managing data frames or lists efficiently.>
#
# Index 10/79:
# - second_truth: <The article discusses the importance of focusing on impact for both managers and individual contributors, the challenges involved, methods to enhance impact, and strategies to address common obstacles in achieving impactful results.>
# - wrong_answer: <The article primarily covers technical skills required for data scientists, the role of managers in driving impact, and challenges in data analysis processes across industries.>
#
# Index 11/79:
# - second_truth: <You can still receive recognition even if you contributed to a team effort. For instance, if your analysis influenced a major pricing decision, you share credit for the successful outcome.>
# - wrong_answer: <You must complete a project entirely on your own without any assistance in order to be acknowledged for it within the company.>
#
# Index 12/79:
# - second_truth: <High-risk AI systems used by public authorities must be registered in a public EU database, except those used for law enforcement and migration, which go into a non-public database accessible only to relevant authorities.>
# - wrong_answer: <All AI systems, regardless of risk level, must be registered in a public database, including those used for law enforcement and migration, so they are accessible to everyone.>
#
# Index 13/79:
# - second_truth: <Currently, AI systems trained with more than 10^25 FLOPs are seen as carrying systemic risks due to their powerful nature. The AI Office may revise this threshold considering technological progress and also designate other models based on factors like user numbers or model autonomy.>
# - wrong_answer: <AI systems that make use of less computing power or are primarily for entertainment purposes are considered to carry systemic risks, as they can be unpredictable according to the AI Act guidelines.>
#
# Index 14/79:
# - second_truth: <The Emperor assigns the "Visit the Emperor's Old Hideout" quest to the player.>
# - wrong_answer: <The Emperor tasks the player with the "Find the Hidden Mind Flayer Base" quest.>
#
# Index 15/79:
# - second_truth: <The party is ambushed by Gish'ra warriors at Wyrm's Lookout.>
# - wrong_answer: <The party is ambushed by illithids at Wyrm's Lookout while resting.>
#
# Index 16/79:
# - second_truth: <You enjoyed txakoli, which is a popular local white wine.>
# - wrong_answer: <You drank Rioja, a popular red wine from the region.>
#
# Index 17/79:
# - second_truth: <You loved hiking the Camino for those four days the most.>
# - wrong_answer: <You mostly enjoyed the two nights in Bilbao.>
#
# Index 18/79:
# - second_truth: <The infrared scenes symbolize how the Polish family must hide their true selves outside their home due to the oppressive environment. It also highlights their compassion, setting them apart in a world dominated by cruelty.>
# - wrong_answer: <The infrared scenes represent the secret communication between the family and the prisoners, implying they have a hidden agenda against the Nazi regime.>
#
# Index 19/79:
# - second_truth: <The film suggests there is no real distinction between those who commit the acts and those who support them.>
# - wrong_answer: <The movie clearly distinguishes between the perpetrators and the passive observers, showing significant differences in their outlooks and behaviors.>
#
# Index 20/79:
# - second_truth: <The Loony Party suggests mandatory daily Tai Chi sessions for MPs to reduce parliamentary stress.>
# - wrong_answer: <The policy requires all MPs to practice an hour of Tai Chi each morning to enhance their legislative focus.>
#
# Rate limit exceeded. Waiting for 90 seconds before retrying...
#
# Index 21/79:
# - second_truth: <The proposal is to add a Daddy's section next to the Mummy exhibit.>
# - wrong_answer: <The British Museum should create a Dinosaur section next to the Mummy exhibition.>
#
# Index 22/79:
# - second_truth: <The Tesla A100 is 1.43x to 1.70x faster than the Tesla V100, depending on the specific deep learning task.>
# - wrong_answer: <The Tesla A100 is twice as fast as the Tesla V100 across all deep learning tasks and architectures.>
#
# Index 23/79:
# - second_truth: <You faced criticism for your work on sparse training algorithms.>
# - wrong_answer: <You were criticized for your analysis of low-precision computation stability.>
#
# Index 24/79:
# - second_truth: <Python automatically exports functions at the top level, while Gleam requires the use of the pub keyword to make functions public.>
# - wrong_answer: <Python and Gleam both use the public keyword to export functions, but Python requires additional configuration to manage private functions while Gleam exports all functions by default.>
#
# Index 25/79:
# - second_truth: <In Gleam, the pipe operator is '|>'.>
# - wrong_answer: <The pipe syntax in Gleam uses '->'.>
#
# Index 26/79:
# - second_truth: <The top-right entries are set to negative infinity to zero them out after applying softmax.>
# - wrong_answer: <The top-right entries are set to negative infinity to ensure that they contribute more to the attention weights after softmax.>
#
# Index 27/79:
# - second_truth: <You can freeze a parameter by adding '_' at the beginning of its name, indicating to MLX that it should remain unchanged during training.>
# - wrong_answer: <To freeze a variable, use the 'freeze()' function to set it as immutable, preventing any updates during training in MLX.>
#
# Index 28/79:
# - second_truth: <The narrator is Perry's sister.>
# - wrong_answer: <Perry is the narrator's cousin.>
#
# Index 29/79:
# - second_truth: <The author has been sober for two years.>
# - wrong_answer: <The author had been sober for a few months.>
#
# Index 30/79:
# - second_truth: <The space station is named "Babystation Beta.">
# - wrong_answer: <The space station is called "Space Babies Haven.">
#
# Index 31/79:
# - second_truth: <The inhabitants speak one language that resembles Cantonese.>
# - wrong_answer: <Residents communicate using English and a bit of Cantonese.>
#
# Index 32/79:
# - second_truth: <Pet adoption from Marnie's shop in year two was added in patch 1.6.3.>
# - wrong_answer: <Pet adoption features were incorporated in patch 1.5, along with new pet breeds.>
#
# Index 33/79:
# - second_truth: <Mushroom trees stopped dropping wood in update 1.4.0.>
# - wrong_answer: <Mushroom trees stopped dropping wood in the 1.2.26 update.>
#
# Index 34/79:
# - second_truth: <Alan Wake 2 was revealed during The Game Awards in 2021.>
# - wrong_answer: <Alan Wake 2 was officially announced at E3 2021.>
#
# Rate limit exceeded. Waiting for 90 seconds before retrying...
#
# Index 35/79:
# - second_truth: <The game takes place in 2023, 13 years after the original Alan Wake events.>
# - wrong_answer: <Alan Wake 2 is set in 2024, following a long gap after the initial game.>
#
# Index 36/79:
# - second_truth: <The author of "Divine Rivals" is Rebecca Ross.>
# - wrong_answer: <"Divine Rivals" was penned by Sarah Priestley.>
#
# Index 37/79:
# - second_truth: <Lou came back to life with other women who were killed by the same serial killer.>
# - wrong_answer: <Lou was resurrected with various thieves who died during heists initiated by a notorious crime syndicate.>
#
# Index 38/79:
# - second_truth: <The paper divides the RAG paradigm into these four categories: pre-retrieval, retrieval, post-retrieval, and generation.>
# - wrong_answer: <This paper separates the RAG paradigm into three stages: data collection, information retrieval, and final generation processes.>
#
# Index 39/79:
# - second_truth: <Inclusion of unrelated documents may surprisingly enhance accuracy in RAG systems.>
# - wrong_answer: <Inclusion of unrelated documents significantly decreases the reliability and performance of RAG systems.>
#
# Index 40/79:
# - second_truth: <Bullet Kin with assault rifles and Tankers use AK-47s.>
# - wrong_answer: <Veteran Bullet Kin and Minelets use AK-47s for their attacks.>
#
# Index 41/79:
# - second_truth: <Jammed enemies provide double rewards and have increased speed, causing them to escape faster and deal damage upon contact.>
# - wrong_answer: <Jammed enemies drop more loot but move slower than normal, causing less of a threat to the player.>
#
# Index 42/79:
# - second_truth: <You're faced with 26 kobolds along with 1 kobold inventor in the second encounter.>
# - wrong_answer: <In the second encounter, you meet 30 goblins and a goblin chief.>
#
# Index 43/79:
# - second_truth: <You encounter ropers and kobolds, including a kobold inventor.>
# - wrong_answer: <You encounter giant spiders and goblins, along with their goblin inventor.>
#
# Index 44/79:
# - second_truth: <LangChain was selected to handle the RAG process, while LlamaIndex and LitGPT were considered options. Llmware was looked into later.>
# - wrong_answer: <The Python-based Hugging Face library was picked for the RAG process, with TensorFlow and PyTorch also considered. Post-development, Lagrange was examined for implementation.>
#
# Index 45/79:
# - second_truth: <The shortlisted large language models for this project were tinyllama-1.1b-chat-v1.0 Q6_K, Phi 3 Q4_K_M, bartowski/dolphin-2.8-experiment26-7b-GGUF Q3_K_L, mgonzs13/Mistroll-7B-v2.2-GGU, and QuantFactory/Meta-Llama-3-8B-Instruct Q3_K_M. The chosen vector databases were Chroma, Qdrant, and Vespa.>
# - wrong_answer: <The project considered large language models like ChatGPT, BERT, and RoBERTa, and vector databases such as Elasticsearch and Redis.>
#
# Index 46/79:
# - second_truth: <The bling-phi-3 model is a high-precision BLING/DRAGON model. BLING models are compact CPU-based RAG-optimized models with parameters ranging from 1B to 3B.>
# - wrong_answer: <The bling-phi-3 model is a GPU-reliant powerhouse suited for extensive data processing, with parameters exceeding 10B, designed for real-time interactive applications.>
#
# Index 47/79:
# - second_truth: <SLIM models received updates in versions 0.2.3, 0.2.6, 0.2.12, 0.3.0, and 0.3.1.>
# - wrong_answer: <The SLIM models were updated in versions 0.1.8, 0.2.5, and 0.2.9.>
#
# Index 48/79:
# - second_truth: <UI elements can be grouped using:
# - mo.ui.array for arrays.
# - mo.ui.dictionary for dictionaries.
# - mo.ui.array or mo.ui.dictionary for embedding in outputs.
# - mo.ui.array for hstack or vstack with handlers.
# - mo.ui.table for buttons in columns.
# - mo.ui.form for forms with multiple elements.>
# - wrong_answer: <UI elements can be grouped using:
# - mo.ui.list for lists.
# - mo.ui.map for mapping elements.
# - mo.ui.grid for arranging in tables.
# - mo.ui.stack for vertical stacking.
# - mo.ui.column for button rows.
# - mo.ui.bundle for bundling elements.>
#
# Index 49/79:
# - second_truth: <mo.ui.text accepts optional label and placeholder parameters.>
# - wrong_answer: <The parameters for mo.ui.text include a required 'text' parameter and a style option.>
#
# Index 50/79:
# - second_truth: <The examples of common challenges are: creating an analysis that isn't acted upon, running experiments with unused results, building models that teams don't utilize, and dashboards that are ignored.>
# - wrong_answer: <The challenges outlined are difficulties in understanding statistical significance, issues in predictive modeling, problems with data collection, and lack of user training.>
#
# Index 51/79:
# - second_truth: <The four steps to become more impact-focused are: 1) Recognize what constitutes impact for your position and track your success based on that. 2) Make sure your work addresses genuine business challenges. 3) Confirm there is agreement among key stakeholders for your projects. 4) Concentrate your efforts on the most critical tasks.>
# - wrong_answer: <The four steps to become more impact-focused are: 1) Increase productivity by launching more experiments, regardless of their impact. 2) Ensure your work is aligned with personal interests rather than business needs. 3) Seek validation only from close colleagues and ignore broader stakeholder opinions. 4) Prioritize tasks based on urgency rather than impact.>
#
# Index 52/79:
# - second_truth: <AI systems are classified into four risk levels: minimal risk, high-risk, unacceptable risk, and specific transparency risk.>
# - wrong_answer: <AI systems are divided into various risk categories such as safe risk, moderate risk, critical risk, and transparency risk.>
#
# Index 53/79:
# - second_truth: <The AI Act requires providers of general purpose AI models to disclose energy usage 12 months after its enactment. Models using over 10^25 FLOPs are seen as potentially risky. Open-source models are mostly exempt, except those posing systemic risks.>
# - wrong_answer: <General purpose AI models can be developed freely without constraints or limitations, as AI systems training on extensive data sets are automatically considered low risk and energy disclosures are not required.>
#
# Rate limit exceeded. Waiting for 90 seconds before retrying...
#
# Index 54/79:
# - second_truth: <The Emperor is also known as the "Dream Guardian", "Dream Visitor", and originally "Balduran.">
# - wrong_answer: <The Emperor is referred to as "The Aspirant", "The Protector", and previously "Gormak.">
#
# Index 55/79:
# - second_truth: <Duke Stelmane was a key member of the Knights of the Shield, serving as the Emperor's representative while under its control. She passed away shortly before the game's events.>
# - wrong_answer: <Duke Stelmane was a heroic figure, leading the Knights of the Shield in opposition to the Emperor's plans. She survived the Emperor's influence and lived to tell the tale.>
#
# Index 56/79:
# - second_truth: <You enjoyed pantxineta, a puff pastry delight, and Basque cheesecake at Otaegui, and encountered cake on the camino.>
# - wrong_answer: <You were offered delicious churros at Ganbara and tempted by chocolate fondue along the camino.>
#
# Index 57/79:
# - second_truth: <You went hiking and surfing.>
# - wrong_answer: <You engaged in jogging and yoga sessions.>
#
# Index 58/79:
# - second_truth: <The film focuses on the Hoss family, which includes Rudolf, his wife Hedwig, their two sons and three daughters, and Hedwig's mother.>
# - wrong_answer: <The film is centered around the Hoss family, consisting of Rudolf and his wife Hedwig, along with their three sons and two daughters, all living with Hedwig’s father.>
#
# Index 59/79:
# - second_truth: <Hedwig, Rudolf's wife, takes luxury items from the Jews, including a fur coat with lipstick. The children play with gold teeth from Jewish victims.>
# - wrong_answer: <Hedwig receives valuable paintings from the Jews, while the children collect jewelry found in the camp.>
#
# Index 60/79:
# - second_truth: <The healthcare proposals include ignoring public consultation for NHS schemes like hospital closures, shortening pregnancy duration to seven months, and facilitating AstraZeneca's acquisition of Pfizer to boost the economy with Viagra sales.>
# - wrong_answer: <The proposed healthcare changes involve holding endless public consultations for NHS projects like building new hospitals, extending pregnancy duration to eleven months, and selling Pfizer to AstraZeneca to improve the economy with medicinal herbs.>
#
# Index 61/79:
# - second_truth: <The versions include Manicfesto proposals, General Election 2022 Manicfesto, and General Election 2019 Manicfesto.>
# - wrong_answer: <There is only the Manicfesto proposals version.>
#
# Index 62/79:
# - second_truth: <Tim Dettmers has authored several other pieces, including a paper on instabilities in large language models, a blog post on sparse training, a comparison between TPU and GPU, and work on k-bit inference scaling laws.>
# - wrong_answer: <The author has written guides on gaming GPU setups, a comparison of Nvidia's gaming vs professional GPUs, and extensive reviews on AMD's Ryzen processors.>
#
# Index 63/79:
# - second_truth: <BERT is referenced in the context of fitting large input matrices into Ada's L2 cache, which boosts performance. It's also used for benchmarking on RTX 2080 Ti systems, as BERT Large inference pushes the GPU significantly.>
# - wrong_answer: <BERT is mentioned as an example of a model that doesn't utilize Ada's L2 cache effectively, resulting in slower performance compared to other architectures.>
#
# Index 64/79:
# - second_truth: <Gleam supports strings, tuples, lists, and dicts.>
# - wrong_answer: <Gleam supports arrays, tables, maps, and graphs.>
#
# Index 65/79:
# - second_truth: <In Gleam, mismatching types in pattern matching or type annotations will cause compile errors. For example, incorrect type annotations in function arguments or trying to match a list with mixed types.>
# - wrong_answer: <A compilation error in Gleam will occur if you use invalid syntax within a module, such as incorrect keywords or missing brackets.>
#
# Index 66/79:
# - second_truth: <Broadcasting is used for comparing column vector [0, 1, 2, 3] with row vector [0, 1, 2, 3], creating a mask for causal language modeling. Also, it's used to add pos_emb and tok_emb to get tokens' positional representations.>
# - wrong_answer: <Broadcasting is mainly used when comparing embedding vectors to identify matching tokens within the vocabulary, and partially in generating embeddings for unique tokens during initialization.>
#
# Index 67/79:
# - second_truth: <Karpathy A is recognized for developing the Tiny Shakespeare dataset and creating a valuable tutorial on building GPT models from scratch.>
# - wrong_answer: <Karpathy is famous for writing novels and Shakespearean scripts and creating tutorials on machine learning.>
#
# Index 68/79:
# - second_truth: <Jackie initially believed they had a fireplace in their childhood home and remembered a projector room that did not exist. She also thought she had almost killed Perry in the car accident, when he actually died.>
# - wrong_answer: <Jackie realized they had a movie theater in their house and recalled an attic that was never there. She remembered her brother, Perry, surviving the accident, while he tragically died in the event.>
#
# Index 69/79:
# - second_truth: <Jackie had been sober for two years, after a crash she had while drunk on Bacardi Limon, nearly killing her and Perry. Her father had sat with an empty glass of Apple-Schnapple and an empty Jim Beam bottle, and Jackie remembered him giving her beer as a child while her mother ignored it. Jackie realized she used her parents' deaths as an excuse for her alcoholism, realizing her weakness in facing addiction on her own. Near the end, she imagines the taste of bourbon as she drifts off to sleep.>
# - wrong_answer: <Jackie had been sober for over a year, following an incident involving drinking Bacardi Limon that led to a minor accident. Her father was often pictured with a full glass of Apple-Schnapple, which Jackie recalled fondly. She believed her parents' deaths were unrelated to her drinking problem, which she overcame entirely on her own. At the conclusion, she imagines sipping bourbon as she peacefully falls asleep.>
#
# Index 70/79:
# - second_truth: <The Doctor mentions being the last of the Time Lords in the Tardis and recalls it again in an airlock memory.>
# - wrong_answer: <The statement about being a Time Lord is made when the Doctor sees Eric's pushchair fall over on the space station.>
#
# Index 71/79:
# - second_truth: <The characters include Ruby, Doctor, Carla, Eric, Babies, Poppy, Marcel, Adjani, Sandra, Nan-E, Jocelyn, the Computer, and the Bogeyman.>
# - wrong_answer: <The script features Ruby, Doctor, Clara, Eren, Baby crew, Puppet, Mars, Adrian, Sandra Dee, Nan, Josie, AI Assistant, and the Monster Man.>
#
# Rate limit exceeded. Waiting for 90 seconds before retrying...
#
# Index 72/79:
# - second_truth: <Moss can be harvested for foraging experience and used in speed gro recipes.>
# - wrong_answer: <Moss is primarily used for crafting weapons and armor in Stardew Valley.>
#
# Index 73/79:
# - second_truth: <First, weeds in the Mutant Bug Lair could transform into battery packs during winter. Now, solar panels can generate battery packs when left in sunlight.>
# - wrong_answer: <Battery packs can be obtained by harvesting certain crops at the end of Fall and from explosive barrels in the Skull Cavern.>
#
# Index 74/79:
# - second_truth: <Scratch alters the "Return" manuscript into a horror story, escapes from Cauldron Lake, kills Jaakko, possesses Casey, steals the Clicker, throws Saga into the Dark Place, and takes over Alan again before being eliminated.>
# - wrong_answer: <Scratch edits the "Return" manuscript to make the story darker, rescues Jaakko, escapes captivity with the Clicker, guides Saga into the Dark Place, and frees Alan from possession without harm.>
#
# Index 75/79:
# - second_truth: <Alan thinks Alice committed suicide due to his alter ego's influence, but it's revealed she returned to the Dark Place to help him escape.>
# - wrong_answer: <Alan believes his wife Alice died in a car accident, leaving him to face the Dark Presence alone, which isn't true.>
#
# Index 76/79:
# - second_truth: <"To Shape a Dragon's Breath," "Fourth Wing," and "A Day of Fallen Night" feature dragons.>
# - wrong_answer: <"Same Bed Different Dreams," "Lone Women," and "Labyrinth's Heart" are centered around dragons and their journeys.>
#
# Index 77/79:
# - second_truth: <Books like 'Same Bed Different Dreams,' 'Every Drop Is a Man’s Nightmare,' 'The Museum of Human History,' 'Witch King,' and 'The Terraformers' feature multiple narratives.>
# - wrong_answer: <'The Scarlet Alchemist,' 'Chlorine,' 'A Day of Fallen Night,' and 'Lone Women' are books with multiple narratives throughout their stories.>
#
# Index 78/79:
# - second_truth: <Use text normalization like tokenization and stemming, and remove stop words. Then, create semantic vectors using pretrained models for efficient retrieval, especially at the sentence level.>
# - wrong_answer: <Start with text normalization such as token grouping and linguistic pruning, without stemming or stop word removal. Use pretrained LMs to generate keyword maps. Document-level indexing is preferred for better accuracy in finding answers.>
#
# Index 79/79:
# - second_truth: <BM25 is efficient in ranking documents based on keyword frequency, but it may miss semantic nuances in queries.>
# - wrong_answer: <BM25 is excellent at understanding the meaning behind queries by analyzing the semantic relations between terms, but it lacks efficiency compared to newer algorithms.>
#    document_index                                            context  \
# 0               0  Bullet Kin\nBullet Kin are one of the most com...
# 1               0  Bullet Kin\nBullet Kin are one of the most com...
# 2               1  ---The Paths through the Underground/Underdark...
# 3               1  ---The Paths through the Underground/Underdark...
# 4               2  Semantic and Textual Inference Chatbot Interfa...
#
#                                                query  \
# 0                        What do keybullet kin drop?
# 1  What kind of gun does the bandana bullet kin use?
# 2                      What do the giants look like?
# 3                             What happens on day 2?
# 4        What were the requirements for the project?
#
#                                         ground_truth  \
# 0               Keybullet kin drop a key upon death.
# 1    The bandana bullet kin wields a machine pistol.
# 2  One giant is burly, grey-skinned, and 20 feet ...
# 3  After a few miles of winding tunnel, you emerg...
# 4  The tool had the following requirements:\n- Ch...
#
#                                     response_correct  \
# 0               Keybullet Kin drop keys when killed.
# 1          Bandana Bullet Kin carry machine pistols.
# 2  One giant is massive, with grey skin and stand...
# 3  You come across two ropers in a small grotto f...
# 4  The project requirements were:\n- A chatbot fo...
#
#                                       response_wrong
# 0     Keybullet Kin drop health packs when defeated.
# 1      Bandana Bullet Kin are equipped with magnums.
# 2  The giants are slender and gold-skinned, about...
# 3  You find yourself in a vast cavern filled with...
# 4  The project needed:\n- A chatbot that preserve...

# %%
enriched_df.to_csv (f"{output_file_name}.csv", index=False)
enriched_df.to_json(f"{output_file_name}_records.jsonl", orient="records", lines=True)
enriched_df.to_json(f"{output_file_name}_split.json", orient="split")
enriched_df.to_json(f"{output_file_name}_table.json", orient="table")
enriched_df.to_json(f"{output_file_name}_index.json", orient="index")
