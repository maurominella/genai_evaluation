# %% [markdown]
# # Variables, Constants and Libraries definition

# %%
from dotenv import load_dotenv # requires python-dotenv
from azure.identity import DefaultAzureCredential, get_bearer_token_provider #requires azure-identity
from openai import AzureOpenAI
import openai, os, json, time, glob, kagglehub # openai is used for error catching, otherwise we use AzureOpenAI
import pandas as pd

load_dotenv("./../config/credentials_my.env")

openai_endpoint       = os.environ["azure_openai_endpoint"]
openai_api_key        = os.environ["azure_openai_api_key"]
openai_api_version    = os.environ["openai_api_version"]
azure_deployment_name = os.environ["azure_openai_chat_deployment_name"]

credential            = DefaultAzureCredential()

token_provider        = get_bearer_token_provider(
    DefaultAzureCredential(), "https://cognitiveservices.azure.com/.default")

folder_path = "./enrichment"

# Create the folder if it doesn't exist
os.makedirs(folder_path, exist_ok=True)
output_file_name = os.path.join(folder_path, "questions_enriched")

# Get the current user's home directory
home_dir = os.path.expanduser("~")

# %% [markdown]
# # [Single-Topic RAG Evaluation Dataset](https://www.kaggle.com/datasets/samuelmatsuoharris/single-topic-rag-evaluation-dataset) retrieval

# %%
# Define the relative path from the home directory for the Kaggle dataset
dataset_relative_path = ".cache/kagglehub/datasets/samuelmatsuoharris/single-topic-rag-evaluation-dataset/versions/3"

dataset_path = os.path.join(home_dir, dataset_relative_path)

if not os.path.exists(dataset_path):
    dataset_path = kagglehub.dataset_download("samuelmatsuoharris/single-topic-rag-evaluation-dataset") # Download latest version

print("Path to dataset files:", dataset_path)

# Find all CSV files in the directory
csv_files = glob.glob(os.path.join(dataset_path, "*.csv"))

# Load each CSV file into a DataFrame and store them in a list
dfs = [(os.path.splitext(os.path.basename(file))[0], pd.read_csv(file)) for file in csv_files]
i=0
for df in dfs:
    print(f"\n\ndataframe #{i} <{df[0]}>:")
    display(df[1].head())
    i+=1
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/samuelmatsuoharris/single-topic-rag-evaluation-dataset?dataset_version_number=3...
# 100%|████████████████████████████████████████████████████████████████████████████████| 263k/263k [00:00<00:00, 880kB/s]
# Extracting files...
# Path to dataset files: C:\Users\mauromi\.cache\kagglehub\datasets\samuelmatsuoharris\single-topic-rag-evaluation-dataset\versions\3
#
#
# dataframe #0 <documents>:
#    index                                         source_url  \
# 0      0  https://enterthegungeon.fandom.com/wiki/Bullet...
# 1      1  https://www.dropbox.com/scl/fi/ljtdg6eaucrbf1a...
# 2      2  https://bytes-and-nibbles.web.app/bytes/stici-...
# 3      3              https://github.com/llmware-ai/llmware
# 4      4                https://docs.marimo.io/recipes.html
#
#                                                 text
# 0  Bullet Kin\nBullet Kin are one of the most com...
# 1  ---The Paths through the Underground/Underdark...
# 2  Semantic and Textual Inference Chatbot Interfa...
# 3  llmware\n\nBuilding Enterprise RAG Pipelines w...
# 4  Recipes\nThis page includes code snippets or “...
# dataframe #1 <multi_passage_answer_questions>:
#    document_index                                           question  \
# 0               0                  Which enemy types wield an AK-47?
# 1               0               What makes jammed enemies different?
# 2               1  What enemies are encountered in the second enc...
# 3               1     What monsters are encountered in this journey?
# 4               2  What framework was chosen to execute the RAG p...
#
#                                               answer
# 0  Assault-rifle wielding Bullet and Tankers wiel...
# 1  Jammed Keybullet Kin drop 2 keys instead of 1,...
# 2  26 kobolds and 1 kobold inventor are encounter...
# 3  Ropers, kobolds, kobold inventors, fire giants...
# 4  The LangChain framework was used to orchestrat...
# dataframe #2 <no_answer_questions>:
#    document_index                                          question
# 0               0  How much health does the Mutant Bullet Kin have?
# 1               0                       Where can bishops be found?
# 2               1                          What happened on day 10?
# 3               1                         What did the goblins say?
# 4               2      Why was the H100 GPU chosen for computation?
# dataframe #3 <single_passage_answer_questions>:
#    document_index                                           question  \
# 0               0                        What do keybullet kin drop?
# 1               0  What kind of gun does the bandana bullet kin use?
# 2               1                      What do the giants look like?
# 3               1                             What happens on day 2?
# 4               2        What were the requirements for the project?
#
#                                               answer
# 0               Keybullet kin drop a key upon death.
# 1    The bandana bullet kin wields a machine pistol.
# 2  One giant is burly, grey-skinned, and 20 feet ...
# 3  After a few miles of winding tunnel, you emerg...
# 4  The tool had the following requirements:\n- Ch...

# %%
docs_df      = dfs[0][1] # documents
ko_df        = dfs[2][1] # no_answer_questions
questions_df = pd.concat([dfs[3][1], dfs[1][1]]) # single_passage_answer_questions + multi_passage_answer_questions

# %% [markdown]
# # Open AI client via Azure OpenAI SDK (with Responses API's)

# %%
client = AzureOpenAI(
    azure_ad_token_provider = token_provider,
    api_version = openai_api_version)

response = client.responses.create(
    model = azure_deployment_name,
    input="how can I make a good pizza?")

print(f"Response: {response.output_text[:30]}...")
# Out:
# Response: Making a great pizza involves ...

# %% [markdown]
# # Create full evaluation dataset

# %%
def enrich_dataset(content: dict) -> dict:

    system_message = """
    given a json dictionary whose keys are "context", "question", "correct_answer", please generate two outputs:
    1) "second_truth": another correct answer, possibly shorter and simpler, equivalent to the original one but with different words.
    2) "wrong_answer": a wrong answer that is contextualized and may look correct to a person who doesn't know the document well, using the same style as the ground truth and the second truth
    """

    input = [
        {"role": "system", "content": system_message},
        {"role": "user", "content": json.dumps(content)}
    ]
    
    text = {
        "format": {
            "type": "json_schema",
            "name": "enriched_dataset",
            "schema": {
                "type": "object",
                "properties": {
                    "second_truth": {"type": "string"},
                    "wrong_answer": {"type": "string"}
                },
                "required": ["second_truth", "wrong_answer"],
                "additionalProperties": False
            },
            "strict": True
        }
    }

    response = client.responses.create(
        model = azure_deployment_name,
        input = input,
        text  = text
    )

    return json.loads(response.output_text)

# %% [markdown]
# # Consolidate the source dataframes into a single one called `consolidated_df`

# %%
# Join DataFrames on docs_df.index == multi_df.document_index
consolidated_df = questions_df.merge(docs_df, left_on='document_index', right_on='index')

# Rename columns
consolidated_df = consolidated_df.rename(columns={'text': 'context', 'answer': 'correct_answer'})

# Drop unwanted columns
consolidated_df = consolidated_df.drop(columns=['index', 'source_url'])

# Reorder columns
consolidated_df = consolidated_df[['document_index', 'context', 'question', 'correct_answer']]

consolidated_df.head()
# Out:
#    document_index                                            context  \
# 0               0  Bullet Kin\nBullet Kin are one of the most com...
# 1               0  Bullet Kin\nBullet Kin are one of the most com...
# 2               1  ---The Paths through the Underground/Underdark...
# 3               1  ---The Paths through the Underground/Underdark...
# 4               2  Semantic and Textual Inference Chatbot Interfa...
#
#                                             question  \
# 0                        What do keybullet kin drop?
# 1  What kind of gun does the bandana bullet kin use?
# 2                      What do the giants look like?
# 3                             What happens on day 2?
# 4        What were the requirements for the project?
#
#                                       correct_answer
# 0               Keybullet kin drop a key upon death.
# 1    The bandana bullet kin wields a machine pistol.
# 2  One giant is burly, grey-skinned, and 20 feet ...
# 3  After a few miles of winding tunnel, you emerg...
# 4  The tool had the following requirements:\n- Ch...

# %% [markdown]
# # Enrich `consolidated_df` into `enriched_df`

# %%
# Initialize empty lists for the new columns
second_truth_list = []
wrong_answer_list = []

enriched_df = consolidated_df.copy()

i = 0
total_rows = len(enriched_df)-1

# Iterate over the rows using a loop
for _, row in enriched_df.iterrows():
    if i >= len(second_truth_list):
        while True:
            try:
                # Call enrich_dataset() for each row
                enriched_data = enrich_dataset({
                    "context": row['context'],
                    "question": row['question'],
                    "correct_answer": row['correct_answer']
                })

                # Ensure the expected keys exist
                if 'second_truth' in enriched_data and 'wrong_answer' in enriched_data:
                    second_truth_list.append(enriched_data['second_truth'])
                    wrong_answer_list.append(enriched_data['wrong_answer'])

                    print(f"Index {i}/{total_rows}:\n- second_truth: <{second_truth_list[i]}>\n- wrong_answer: <{wrong_answer_list[i]}>\n")
                    break  # Exit loop on success
                else:
                    print("Missing keys in enriched_data, retrying...\n")
            except openai.RateLimitError:
                print("Rate limit exceeded. Waiting for 90 seconds before retrying...\n")
                time.sleep(90)  # Wait before retrying
    else:
        print(f"Index {i}/{total_rows} (skipping):\n- second_truth: <{second_truth_list[i]}>\n- wrong_answer: <{wrong_answer_list[i]}>\n")

    i += 1


# Assign the lists as new columns in the DataFrame
enriched_df['second_truth'] = second_truth_list
enriched_df['wrong_answer'] = wrong_answer_list

# Display the updated DataFrame
display(enriched_df.head())
# Out:
# Index 0/79:
# - second_truth: <Keybullet Kin drop a key when defeated.>
# - wrong_answer: <Keybullet Kin drop health potions when destroyed.>
#
# Index 1/79:
# - second_truth: <Bandana Bullet Kin use machine pistols.>
# - wrong_answer: <Bandana Bullet Kin wield AK-47s.>
#
# Index 2/79:
# - second_truth: <One giant is muscular, with gray skin, 20 feet tall, wearing dark iron armor with sharp metal edges. It leans against the wall, holding two large and spiked shields.
#
# The other giant is tall, in lighter iron armor, holding a huge maul, and appears uninterested.>
# - wrong_answer: <The giants have a shiny, metallic appearance and are 10 feet tall. They wear robes made from soft underground fibers and carry small wooden staffs, showing signs of curiosity.>
#
# Index 3/79:
# - second_truth: <You enter a small grotto with dripping rock formations and face two ropers.>
# - wrong_answer: <You find a dry grotto filled with abandoned mining tools and remnants of other travelers.>
#
# Index 4/79:
# - second_truth: <The project needs to be a locally run, fast and efficient chatbot that retrieves information from unstructured text files and can indicate if it doesn't have an answer.>
# - wrong_answer: <The tool must be able to access the internet for real-time information, have built-in conversational memory, and run efficiently on any machine, regardless of size.>
#
# Index 5/79:
# - second_truth: <The prototype was tested using Wikipedia pages for Grace Hopper and Alan Turing.>
# - wrong_answer: <The prototype was tested using Wikipedia pages for Miles Lawson and COBOL language documentation.>
#
# Index 6/79:
# - second_truth: <To start quickly, you can use SQLite3 and ChromaDB without installation. For larger projects, MongoDB and Milvus offer scalable solutions via Docker. Postgres can be used for both text and vector data through Docker installation. You can also combine different options with support for multiple databases.>
# - wrong_answer: <Use SQLite3 for vector data and Milvus for text collection with Docker. ChromaDB and Pinecone are supported for speedy deployments without file-based setups.>
#
# Index 7/79:
# - second_truth: <Support for UTF-8 encoding for European languages was introduced on April 3rd in version 0.2.7.>
# - wrong_answer: <UTF-8 support for European languages was added in the v0.3.0 Update on June 4th.>
#
# Index 8/79:
# - second_truth: <import marimo as mo
#
# button = mo.ui.button()
# button
#
# mo.stop(not button.value, "Press 'run' to create a random number")
#
# import random
# random.randint(0, 1000).>
# - wrong_answer: <import marimo as mo
#
# button = mo.ui.switch()
# button
#
# mo.stop(button.value, "Click 'run' to generate a sequence")
#
# import random
# random.randint(0, 500).>
#
# Index 9/79:
# - second_truth: <Caching is useful when your notebook includes calculations like t-SNE, UMAP, or PyMDE embeddings.>
# - wrong_answer: <Caching is helpful when you need to run UI interactions faster, such as changing button states quickly.>
#
# Index 10/79:
# - second_truth: <The article discusses the importance of focusing on impact for career growth, challenges in achieving impact, strategies to enhance impact, and ways to overcome obstacles in delivering real impact.>
# - wrong_answer: <The article mainly focuses on how data scientists can increase their technical skills, improve output efficiency, and manage workload to prevent burn-out.>
#
# Index 11/79:
# - second_truth: <It's not necessary to do a task entirely on your own to receive recognition. If your contribution led to a successful outcome, you're entitled to share in the accolades.>
# - wrong_answer: <You must complete a project entirely by yourself to receive any credit for the impact it has. Only individual achievements are recognized.>
#
# Index 12/79:
# - second_truth: <Publicly used high-risk AI systems must be listed in an EU database, except if they deal with law enforcement or migration. These will be recorded privately for oversight.>
# - wrong_answer: <All AI systems, regardless of risk level, need to be registered in a public EU database. Systems for law enforcement and migration are exempt from registration.>
#
# Index 13/79:
# - second_truth: <General-purpose AI models trained with over 10^25 FLOPs are seen as potentially risky, due to their high computational power. This threshold may change with advancements.>
# - wrong_answer: <AI systems used for real-time biometric identification in public spaces are considered to carry systematic risks, especially when they involve large datasets.>
#
# Index 14/79:
# - second_truth: <The player receives the quest "Visit the Emperor's Old Hideout" from the Emperor.>
# - wrong_answer: <The Emperor assigns the "Uncover the Elder Brain's Secrets" quest to the player.>
#
# Index 15/79:
# - second_truth: <The group ambushing the party at Wyrm's Lookout consists of Gish'ra warriors.>
# - wrong_answer: <A band of city guards ambushes the party at Wyrm's Lookout, attacking on their way to Baldur's Gate.>
#
# Index 16/79:
# - second_truth: <You enjoyed txakoli while visiting the pintxo bars.>
# - wrong_answer: <You drank sangria at the pintxo bars.>
#
# Index 17/79:
# - second_truth: <You loved the four days hiking the Camino de Santiago the most.>
# - wrong_answer: <Your favorite part was surfing in San Sebastián.>
#
# Index 18/79:
# - second_truth: <The infrared scenes show how the Polish family hides their true selves in public, symbolizing their struggle to maintain humanity in a cruel world. It differentiates them from the normalcy of Nazi life.>
# - wrong_answer: <The infrared scenes highlight the darker side of the Hoss family, representing their hidden remorse and guilt for their actions during the Holocaust.>
#
# Index 19/79:
# - second_truth: <The film portrays both the perpetrators of evil and those who enable it without distinguishing between them.>
# - wrong_answer: <The Zone of Interest clearly separates those who commit atrocities from those who are merely complicit.>
#
# Index 20/79:
# - second_truth: <The Loony Party wants to relax Parliament by requiring M.Ps to do Tai chi for 30 minutes daily.>
# - wrong_answer: <The Loony Party will offer Tai chi classes only on weekends to help M.Ps manage stress.>
#
# Rate limit exceeded. Waiting for 90 seconds before retrying...
#
# Index 21/79:
# - second_truth: <The museum should add a Daddy section next to the Mummy display.>
# - wrong_answer: <The British Museum should have a Daddy’s section for temporary exhibits only.>
#
# Index 22/79:
# - second_truth: <The Tesla A100 is up to 1.70 times faster than the Tesla V100 in certain deep learning tasks.>
# - wrong_answer: <The Tesla A100 is about 0.70 times faster than the Tesla V100 across most deep learning tasks.>
#
# Index 23/79:
# - second_truth: <You were criticized for your work on training sparse networks.>
# - wrong_answer: <You faced criticism for your research on low-precision computation techniques.>
#
# Index 24/79:
# - second_truth: <Python automatically makes functions available from the top level, meaning they're public. Gleam keeps functions private unless you use the pub keyword to make them public.>
# - wrong_answer: <Both Python and Gleam require a special keyword to export functions, making them visible outside the module. In Python, the keyword is `export`, and in Gleam, it's `pub`. >
#
# Index 25/79:
# - second_truth: <In Gleam, use the '|>' operator for piping.>
# - wrong_answer: <The operator for Pipe in Gleam is '|='.>
#
# Index 26/79:
# - second_truth: <The top-right values are set to negative infinity to ensure they become zero after the softmax, preventing attention to future tokens.>
# - wrong_answer: <The top-right values are set to negative infinity to prioritize attention on future tokens after the softmax.>
#
# Index 27/79:
# - second_truth: <Add '_' before the attribute name to signal MLX to not update it during training.>
# - wrong_answer: <Use the 'freeze_variable()' function provided by MLX to prevent updates during training.>
#
# Index 28/79:
# - second_truth: <Perry is the narrator's sibling.>
# - wrong_answer: <Perry is the narrator's therapist.>
#
# Index 29/79:
# - second_truth: <The narrator has been sober for two years.>
# - wrong_answer: <The narrator had been sober for three years.>
#
# Index 30/79:
# - second_truth: <Babystation Beta is the name of the station.>
# - wrong_answer: <The space station is called "Tardis One.">
#
# Index 31/79:
# - second_truth: <They speak one unified language, which is like Cantonese.>
# - wrong_answer: <They conversed using English, as if it naturally evolved on Pacifico del Rio.>
#
# Index 32/79:
# - second_truth: <Pet adoption from Marnie's shop was introduced in version 1.6.3.>
# - wrong_answer: <Pet adoption was added in version 1.5.6 when the pet bowl feature was introduced.>
#
# Index 33/79:
# - second_truth: <In patch 1.4.0, mushroom trees stopped dropping wood.>
# - wrong_answer: <Mushroom trees stopped dropping wood in patch 1.5.0.>
#
# Rate limit exceeded. Waiting for 90 seconds before retrying...
#
# Index 34/79:
# - second_truth: <Alan Wake 2 was revealed during The Game Awards 2021.>
# - wrong_answer: <Alan Wake 2 was officially announced at Gamescom 2021.>
#
# Index 35/79:
# - second_truth: <The game takes place in 2023, thirteen years following Alan Wake's events.>
# - wrong_answer: <The game is set in 2024, a year after the events at Cauldron Lake began.>
#
# Index 36/79:
# - second_truth: <'Divine Rivals' was authored by Rebecca Ross.>
# - wrong_answer: <'Divine Rivals' was penned by Rebecca Roach.>
#
# Index 37/79:
# - second_truth: <Lou was brought back to life alongside other women killed by the same murderer.>
# - wrong_answer: <Lou inherited a mysterious fortune from the group of murder victims.>
#
# Index 38/79:
# - second_truth: <The paper divides the RAG paradigm into four sections: pre-retrieval, retrieval, post-retrieval, and generation.>
# - wrong_answer: <The paper splits the RAG paradigm into three categories: data integration, query response, and feedback optimization.>
#
# Index 39/79:
# - second_truth: <Including irrelevant documents can surprisingly enhance accuracy according to Noise Power research.>
# - wrong_answer: <Adding unrelated documents usually decreases the accuracy of RAG systems.>
#
# Index 40/79:
# - second_truth: <Tankers and Bullet Kin with assault rifles use AK-47s.>
# - wrong_answer: <Veteran Bullet Kin and Shroomers use AK-47s.>
#
# Index 41/79:
# - second_truth: <Jammed enemies drop more loot, and some can deal contact damage. They also move faster and vanish quicker.>
# - wrong_answer: <Jammed Bullet Kin fire more bullets and have less health, making them easier to defeat for extra loot.>
#
# Index 42/79:
# - second_truth: <In the second encounter, there are 26 kobolds and one kobold inventor.>
# - wrong_answer: <In the second encounter, there are 2 ropers hiding among the kobolds.>
#
# Index 43/79:
# - second_truth: <Ropers, kobolds, kobold inventors, and fire giants.>
# - wrong_answer: <Ropers, kobolds, kobold inventors, and cave trolls.>
#
# Index 44/79:
# - second_truth: <LangChain was used for the RAG process, while Llamaindex and LitGPT were other options considered. After completion, Llmware was also thought about.>
# - wrong_answer: <LitGPT was chosen for the RAG process. LangChain and Llamaindex were considered, and LitGPT was finalized before reading about Llmware later.>
#
# Index 45/79:
# - second_truth: <The large language models shortlisted were tinyllama-1.1b-chat-v1.0, Phi 3, dolphin-2.8-experiment26-7b, Mistroll-7B-v2.2, and Meta-Llama-3-8B. The vector databases shortlisted were Chroma, Qdrant, and Vespa.>
# - wrong_answer: <For this project, the shortlisted large language models were Anthropic's Claude 3 and Google's Gemini 1.5, and the vector databases considered were TensorFlow, PyTorch, and JAX.>
#
# Index 46/79:
# - second_truth: <The bling-phi-3 model is part of the BLING series, known for being small, CPU-friendly, and optimized for Retrieval-Augmented Generation (RAG). It follows instructions and ranges between 1B to 3B parameters. It's the newest accurate BLING/DRAGON model.>
# - wrong_answer: <The bling-phi-3 model is a large, GPU-based RAG-optimized model similar to the DRAGON series, known for its broad applications in enterprise processes.>
#
# Index 47/79:
# - second_truth: <SLIM models received updates in releases 0.2.3, 0.2.6, 0.2.12, 0.3.0, and 0.3.1.>
# - wrong_answer: <The SLIM models saw updates in versions 0.2.8, 0.2.15, 0.3.1, and 0.3.2.>
#
# Index 48/79:
# - second_truth: <You can group UI elements by using arrays, dictionaries, forming dynamic outputs, using hstack/vstack, putting them in tables, and combining them in a form.>
# - wrong_answer: <You can group UI elements together by adding them to a global function that wraps each element individually, using the function 'marimo.wrapper'.>
#
# Index 49/79:
# - second_truth: <You can provide a label and a placeholder, both of which are optional, to mo.ui.text.>
# - wrong_answer: <mo.ui.text requires a name and a type parameter, which are mandatory.>
#
# Index 50/79:
# - second_truth: <Challenges include creating analyses that aren't acted upon, experiments with unused results, unused predictive models, and dashboards that aren't viewed.>
# - wrong_answer: <The challenges include difficulty in coding, issues with data collection methods, limitations in software tools, and problems with online data security.>
#
# Index 51/79:
# - second_truth: <1. Know what impact means for your role and track it.
# 2. Make sure your work addresses actual business challenges.
# 3. Get agreement from stakeholders on your work.
# 4. Spend time on the most important tasks.>
# - wrong_answer: <1. Deliver as many projects as possible.
# 2. Focus on the technical accuracy of your work.
# 3. Allow your manager to take charge of stakeholder discussions.
# 4. Prioritize tasks that are easiest to complete.>
#
# Rate limit exceeded. Waiting for 90 seconds before retrying...
#
# Index 52/79:
# - second_truth: <AI systems are classified into minimal, high, unacceptable, and transparency risk categories.>
# - wrong_answer: <AI systems are grouped into low, medium, high, and critical risk categories.>
#
# Index 53/79:
# - second_truth: <General-purpose AI models trained with over 10^25 FLOPs are seen as potentially risky. Within a year of the AI Act becoming effective, guidelines for overseeing these models are applied. High energy use must be reported by providers. Free and open-source models generally don't have these requirements, except when systemic risks are involved.>
# - wrong_answer: <General-purpose AI models can be developed without strict regulations, as they do not pose significant risks. Energy consumption reporting is optional, and free and open-source models have no obligations, even if they pose systemic risks.>
#
# Index 54/79:
# - second_truth: <The Emperor is also referred to as the 'Dream Guardian,' 'Dream Visitor,' and 'Balduran.'>
# - wrong_answer: <The emperor has been known exclusively as 'The Absolute' and 'Dream Master'.>
#
# Index 55/79:
# - second_truth: <Duke Stelmane was involved with the Knights of the Shield and acted as an envoy for the Emperor while being secretly controlled by it. She passed away before the game's events.>
# - wrong_answer: <Duke Stelmane was a powerful mage in Baldur's Gate, known for her magical alliance with the mind flayers and active participation in their rituals, supporting the Emperor willingly.>
#
# Index 56/79:
# - second_truth: <At Otaegui, you enjoyed puff pastry and Basque cheesecake, and during the camino hike, you were offered cake.>
# - wrong_answer: <You were offered desserts at Ficus Bar, where they serve wonderful meals and sweet treats.>
#
# Index 57/79:
# - second_truth: <You went surfing and hiked on the Camino.>
# - wrong_answer: <You did swimming and cycling through the cities.>
#
# Index 58/79:
# - second_truth: <The film focuses on the Hoss family: Rudolf Hoss, his wife Hedwig, their two sons and three daughters, and Hedwig's mother.>
# - wrong_answer: <The film is centered around Rudolf Hoss and his family, which includes his wife Hedwig and their three daughters.>
#
# Index 59/79:
# - second_truth: <Hedwig, Rudolf's wife, receives luxury items from the Jewish prisoners, including a fur coat with lipstick in the pocket. The children also collect gold teeth from victims.>
# - wrong_answer: <Rudolf's wife, Hedwig, often receives luxury items from Nazi soldiers, but not from Jewish prisoners. The children collect toys from their birthday parties.>
#
# Index 60/79:
# - second_truth: <The healthcare proposals include ignoring public consultations on NHS-related changes, reducing pregnancy duration to seven months, and helping AstraZeneca buy Pfizer to improve economic conditions.>
# - wrong_answer: <The healthcare proposals suggest extending pregnancy to eleven months to boost population growth and implementing a mandatory exercise regime for NHS staff to improve efficiency.>
#
# Index 61/79:
# - second_truth: <The Manicfesto includes proposals for various topics, the 2022 General Election Manicfesto, and the 2019 General Election Manicfesto.>
# - wrong_answer: <The Manicfesto versions only include proposals from the latest General Election Manicfesto.>
#
# Index 62/79:
# - second_truth: <Tim Dettmers has also written papers and blog posts on topics like instabilities in large language models, sparse training, TPU vs GPU comparisons, and k-bit inference scaling laws.>
# - wrong_answer: <Tim Dettmers has written extensively on the history and development of gaming GPUs and a blog post comparing Intel and AMD CPUs.>
#
# Index 63/79:
# - second_truth: <BERT is referred to in training where matrices fit into the Ada GPU's L2 cache. It's also used for benchmarking on the 4x RTX 2080 Ti setup because it's a demanding model.>
# - wrong_answer: <BERT is featured as an example of a model that does not benefit from Ada L2 cache during inference. It is not used for testing on RTX 2080 Ti GPUs as it has low computational demands.>
#
# Index 64/79:
# - second_truth: <Gleam natively supports strings, tuples, and lists.>
# - wrong_answer: <Gleam supports arrays, maps, and objects.>
#
# Index 65/79:
# - second_truth: <Gleam will give a compilation error if there's a type mismatch in pattern matching or if the function type annotations aren't valid. Using float and int together in a list will also cause a compile error.>
# - wrong_answer: <Gleam will compile successfully even if there's a type mismatch in pattern matching or function annotations are incorrect. Using float and int together in a list causes no issues.>
#
# Index 66/79:
# - second_truth: <Broadcasting is used to compare the column vector [0, 1, 2, 3] with the row vector [0, 1, 2, 3] to create the mask for causal language modeling. Additionally, it's used to combine pos_emb and tok_emb to create token representations with positional data.>
# - wrong_answer: <Broadcasting is used to merge the attention weights with the token embeddings, helping to generate the final output of the model and ensuring future tokens are considered in predictions.>
#
# Index 67/79:
# - second_truth: <Karpathy created the Tiny Shakespeare dataset and has an excellent tutorial on building GPT from scratch.>
# - wrong_answer: <Karpathy is known for his work on tokenization algorithms and multi-head attention in LLMs.>
#
# Index 68/79:
# - second_truth: <Jackie incorrectly recalled having a projector room and misremembered the layout of the kitchen doorway in their childhood home. She also remembered Perry surviving the car accident, though he actually died.>
# - wrong_answer: <Jackie remembered the house had a large backyard and she thought her brother Perry was driving during the accident, though neither memory is accurate.>
#
# Index 69/79:
# - second_truth: <Jackie has been sober for seven hundred and thirty days since the accident, which happened because she was driving drunk. Her dad used to give her beer when she was a child, contributing to her addiction. Jackie reflects on how her parents' death had allowed her to excuse her alcoholism.>
# - wrong_answer: <Jackie recalls the time when she and Perry used to enjoy drinking Apple-Schnapple together, a beverage their mother made. Although it was mostly just apple cider, these memories were cherished, and there was no further mention of alcohol turning into a problem throughout her life.>
#
# Index 70/79:
# - second_truth: <The Doctor mentions being the last of the time lords in the Tardis and recalls it again in the airlock.>
# - wrong_answer: <The Doctor describes himself as the last of the time lords during the landing on the space station.>
#
# Rate limit exceeded. Waiting for 90 seconds before retrying...
#
# Index 71/79:
# - second_truth: <Characters include Ruby, the Doctor, Carla, Eric, various Babies, Poppy, Marcel?, Adjani?, Sandra?, Nan-E, Jocelyn, the Computer, and the Bogeyman.>
# - wrong_answer: <The characters in this script are Ruby, the Doctor, and a group of scientists who are studying an alien species on the space station. There are also some robots and an invisible creature.>
#
# Index 72/79:
# - second_truth: <Moss grants foraging experience and is an ingredient for speed gro fertilizer.>
# - wrong_answer: <Moss can be traded for unique hats at the festival shop.>
#
# Index 73/79:
# - second_truth: <Battery packs have been generated by solar panels when left in sunlight, and weeds in the Mutant Bug Lair used to transform into battery packs during winter.>
# - wrong_answer: <Battery packs have always been obtained by fishing them out of the river near the carpenter's shop, and from the community center bundles as rewards.>
#
# Index 74/79:
# - second_truth: <Scratch altered the "Return" manuscript into a horror story affecting the real world. He escapes captivity, kills Jaakko, steals the Clicker, possesses Saga's partner Casey, and then Saga before finally being defeated.>
# - wrong_answer: <Scratch edited a manuscript to create a fictional horror story that had no real impact. He escaped Cauldron Lake unnoticed, helped Jaakko, took the Clicker to protect Saga, and became Alan's ally.>
#
# Index 75/79:
# - second_truth: <Alan is tricked by Alice into thinking she committed suicide, but she actually returned to the Dark Place to help him escape. It's all part of a plan for him to achieve "ascension.">
# - wrong_answer: <Alan is led to believe by his wife Alice that she is collaborating with Scratch to keep him trapped in the Dark Place forever.>
#
# Index 76/79:
# - second_truth: <'To Shape a Dragon’s Breath', 'Fourth Wing', and 'A Day of Fallen Night' feature dragons.>
# - wrong_answer: <The books 'Chain-Gang All-Stars', 'Lone Women', and 'Our Share of Night' have dragons in them.>
#
# Index 77/79:
# - second_truth: <"Same Bed Different Dreams," "Every Drop is a Man’s Nightmare," "The Museum of Human History," "Witch King," and "The Terraformers" feature multiple storylines.>
# - wrong_answer: <The books 'Victory City,' 'Monstrilio,' and 'Starling House' contain multiple narratives woven throughout their stories.>
#
# Index 78/79:
# - second_truth: <Text should be normalized by tokenizing, stemming, and removing stop words to prepare it for indexing. Use pretrained LMs to create semantic vectors for quick and precise retrieval, focusing on sentence-level indexing to find specific answers efficiently.>
# - wrong_answer: <For question-answering, it's best to use document-level indexing without any text preprocessing like tokenization or stemming. This helps in retaining the original context and improves retrieval precision for comprehensive answers.>
#
# Index 79/79:
# - second_truth: <BM25 is efficient but often misses the deeper meaning of queries due to its focus on term frequency.>
# - wrong_answer: <BM25 is highly effective in understanding semantic nuances and does not require much computational power.>
#    document_index                                            context  \
# 0               0  Bullet Kin\nBullet Kin are one of the most com...
# 1               0  Bullet Kin\nBullet Kin are one of the most com...
# 2               1  ---The Paths through the Underground/Underdark...
# 3               1  ---The Paths through the Underground/Underdark...
# 4               2  Semantic and Textual Inference Chatbot Interfa...
#
#                                             question  \
# 0                        What do keybullet kin drop?
# 1  What kind of gun does the bandana bullet kin use?
# 2                      What do the giants look like?
# 3                             What happens on day 2?
# 4        What were the requirements for the project?
#
#                                       correct_answer  \
# 0               Keybullet kin drop a key upon death.
# 1    The bandana bullet kin wields a machine pistol.
# 2  One giant is burly, grey-skinned, and 20 feet ...
# 3  After a few miles of winding tunnel, you emerg...
# 4  The tool had the following requirements:\n- Ch...
#
#                                         second_truth  \
# 0            Keybullet Kin drop a key when defeated.
# 1            Bandana Bullet Kin use machine pistols.
# 2  One giant is muscular, with gray skin, 20 feet...
# 3  You enter a small grotto with dripping rock fo...
# 4  The project needs to be a locally run, fast an...
#
#                                         wrong_answer
# 0  Keybullet Kin drop health potions when destroyed.
# 1                   Bandana Bullet Kin wield AK-47s.
# 2  The giants have a shiny, metallic appearance a...
# 3  You find a dry grotto filled with abandoned mi...
# 4  The tool must be able to access the internet f...

# %%
enriched_df.to_csv (f"{output_file_name}.csv", index=False)
enriched_df.to_json(f"{output_file_name}_records.json", orient="records", lines=True)
enriched_df.to_json(f"{output_file_name}_split.json", orient="split")
enriched_df.to_json(f"{output_file_name}_table.json", orient="table")
enriched_df.to_json(f"{output_file_name}_index.json", orient="index")
